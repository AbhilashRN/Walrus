# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
import Features, EntitiesOptions, KeywordsOptions ,ConceptsOptions
import pandas
abc = ""
response = {}
x = {}
k = 0
df = pandas.read_csv('coref_plot.csv')
y = df["Movie Name"][0]
for i  in range(0,34727):
    x[k] = df["Movie Name"][i]
    if x[k]==y:
        abc = abc +df["Coref Plot"][i]
    else:
        if(abc):
            print("\n")
        
            natural_language_understanding = NaturalLanguageUnderstandingV1(
              username='06320980-d791-4920-834b-3c5368522608',
              password='UKVXqFnwnNnZ',
              version='2018-03-16',
            )
            response[k] = natural_language_understanding.analyze(
              text=abc
        ,
          features=Features(
        concepts=ConceptsOptions(
              limit=8),
          )).get_result()
            print(json.dumps(response[k], indent=2))
        k=k+1
        y=x[k-1]
        abc=""
# Out:
# {
#   "concepts": [
#     {
#       "relevance": 0.98703,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.643126,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.585549,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.549378,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.548032,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.520734,
#       "dbpedia_resource": "http://dbpedia.org/resource/Black-and-white_films",
#       "text": "Black-and-white films"
#     },
#     {
#       "relevance": 0.46901,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mansion",
#       "text": "Mansion"
#     },
#     {
#       "relevance": 0.464702,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inheritance",
#       "text": "Inheritance"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 993
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.954234,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 677
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.909462,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.778111,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.642639,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.619604,
#       "dbpedia_resource": "http://dbpedia.org/resource/Initiative",
#       "text": "Initiative"
#     },
#     {
#       "relevance": 0.569686,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.560287,
#       "dbpedia_resource": "http://dbpedia.org/resource/Killer",
#       "text": "Killer"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1272
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.930018,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.684092,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.680379,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 183
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.959123,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.635762,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.610923,
#       "dbpedia_resource": "http://dbpedia.org/resource/Proposal",
#       "text": "Proposal"
#     },
#     {
#       "relevance": 0.527838,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.466858,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.457401,
#       "dbpedia_resource": "http://dbpedia.org/resource/Proposals_(play)",
#       "text": "Proposals"
#     },
#     {
#       "relevance": 0.415577,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.413973,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1180
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.908364,
#       "dbpedia_resource": "http://dbpedia.org/resource/Higher_education",
#       "text": "Higher education"
#     },
#     {
#       "relevance": 0.90023,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.813147,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Help",
#       "text": "The Help"
#     },
#     {
#       "relevance": 0.79672,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.781682,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inspector",
#       "text": "Inspector"
#     },
#     {
#       "relevance": 0.773888,
#       "dbpedia_resource": "http://dbpedia.org/resource/Education",
#       "text": "Education"
#     },
#     {
#       "relevance": 0.760878,
#       "dbpedia_resource": "http://dbpedia.org/resource/Planning",
#       "text": "Planning"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 812
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.926865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.846864,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.677663,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.654494,
#       "dbpedia_resource": "http://dbpedia.org/resource/India",
#       "text": "India"
#     },
#     {
#       "relevance": 0.578706,
#       "dbpedia_resource": "http://dbpedia.org/resource/Who_Wants_to_Be_a_Millionaire?",
#       "text": "Who Wants to Be a Millionaire?"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2670
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.926012,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.631003,
#       "dbpedia_resource": "http://dbpedia.org/resource/Cleveland_Indians",
#       "text": "Cleveland Indians"
#     },
#     {
#       "relevance": 0.6141,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Trio",
#       "text": "The Trio"
#     },
#     {
#       "relevance": 0.575,
#       "dbpedia_resource": "http://dbpedia.org/resource/Employment",
#       "text": "Employment"
#     },
#     {
#       "relevance": 0.5589,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wage",
#       "text": "Wage"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 617
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.945554,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.763037,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.709981,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inspector",
#       "text": "Inspector"
#     },
#     {
#       "relevance": 0.680891,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police_station",
#       "text": "Police station"
#     },
#     {
#       "relevance": 0.678699,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sub-Inspector",
#       "text": "Sub-Inspector"
#     },
#     {
#       "relevance": 0.634646,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.576097,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sting_(musician)",
#       "text": "Sting"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1296
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.946549,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.548414,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.537888,
#       "dbpedia_resource": "http://dbpedia.org/resource/Demography",
#       "text": "Demography"
#     },
#     {
#       "relevance": 0.456409,
#       "dbpedia_resource": "http://dbpedia.org/resource/Kinship",
#       "text": "Kinship"
#     },
#     {
#       "relevance": 0.439609,
#       "dbpedia_resource": "http://dbpedia.org/resource/Miscegenation",
#       "text": "Miscegenation"
#     },
#     {
#       "relevance": 0.438061,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life",
#       "text": "Life"
#     },
#     {
#       "relevance": 0.415411,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arranged_marriage",
#       "text": "Arranged marriage"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 609
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.972788,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.575136,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.566467,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love_letter",
#       "text": "Love letter"
#     },
#     {
#       "relevance": 0.526582,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hinduism",
#       "text": "Hinduism"
#     },
#     {
#       "relevance": 0.492175,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.481594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.474765,
#       "dbpedia_resource": "http://dbpedia.org/resource/Devi",
#       "text": "Devi"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 756
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.903719,
#       "dbpedia_resource": "http://dbpedia.org/resource/Psychological_abuse",
#       "text": "Psychological abuse"
#     },
#     {
#       "relevance": 0.875731,
#       "dbpedia_resource": "http://dbpedia.org/resource/Victim",
#       "text": "Victim"
#     },
#     {
#       "relevance": 0.850035,
#       "dbpedia_resource": "http://dbpedia.org/resource/Oppression",
#       "text": "Oppression"
#     },
#     {
#       "relevance": 0.840096,
#       "dbpedia_resource": "http://dbpedia.org/resource/Core_issues_in_ethics",
#       "text": "Core issues in ethics"
#     },
#     {
#       "relevance": 0.836371,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Victim_(novel)",
#       "text": "The Victim"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 654
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.894132,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.783167,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.761687,
#       "dbpedia_resource": "http://dbpedia.org/resource/Identity_theft",
#       "text": "Identity theft"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 576
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.898928,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.795386,
#       "dbpedia_resource": "http://dbpedia.org/resource/Truth",
#       "text": "Truth"
#     },
#     {
#       "relevance": 0.793059,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life",
#       "text": "Life"
#     },
#     {
#       "relevance": 0.773487,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.708297,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother-in-law",
#       "text": "Mother-in-law"
#     },
#     {
#       "relevance": 0.67392,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2695
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.930166,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.781793,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.771917,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.703237,
#       "dbpedia_resource": "http://dbpedia.org/resource/Better",
#       "text": "Better"
#     },
#     {
#       "relevance": 0.650354,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.558232,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mental_disorder",
#       "text": "Mental disorder"
#     },
#     {
#       "relevance": 0.556972,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shock",
#       "text": "Shock"
#     },
#     {
#       "relevance": 0.556669,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Terrace",
#       "text": "The Terrace"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1638
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.96148,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.558526,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.453614,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.435505,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.416118,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.385468,
#       "dbpedia_resource": "http://dbpedia.org/resource/Son",
#       "text": "Son"
#     },
#     {
#       "relevance": 0.362452,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.360787,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daughter",
#       "text": "Daughter"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2111
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 89
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.977804,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.804504,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.710628,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.685873,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.672215,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.579733,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     },
#     {
#       "relevance": 0.577556,
#       "dbpedia_resource": "http://dbpedia.org/resource/Actor",
#       "text": "Actor"
#     },
#     {
#       "relevance": 0.562179,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1169
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.941334,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.75002,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.707215,
#       "dbpedia_resource": "http://dbpedia.org/resource/Singing",
#       "text": "Singing"
#     },
#     {
#       "relevance": 0.66525,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.663118,
#       "dbpedia_resource": "http://dbpedia.org/resource/Insane_Clown_Posse",
#       "text": "Insane Clown Posse"
#     },
#     {
#       "relevance": 0.6141,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Asylum",
#       "text": "The Asylum"
#     },
#     {
#       "relevance": 0.613347,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gallows",
#       "text": "Gallows"
#     },
#     {
#       "relevance": 0.611524,
#       "dbpedia_resource": "http://dbpedia.org/resource/Insanity",
#       "text": "Insanity"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1244
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.962982,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.674789,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.604719,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daughter",
#       "text": "Daughter"
#     },
#     {
#       "relevance": 0.565573,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.542862,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     },
#     {
#       "relevance": 0.542566,
#       "dbpedia_resource": "http://dbpedia.org/resource/Money",
#       "text": "Money"
#     },
#     {
#       "relevance": 0.524293,
#       "dbpedia_resource": "http://dbpedia.org/resource/Son",
#       "text": "Son"
#     },
#     {
#       "relevance": 0.406686,
#       "dbpedia_resource": "http://dbpedia.org/resource/Employment",
#       "text": "Employment"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1627
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.919916,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.893348,
#       "dbpedia_resource": "http://dbpedia.org/resource/Black-and-white_films",
#       "text": "Black-and-white films"
#     },
#     {
#       "relevance": 0.840584,
#       "dbpedia_resource": "http://dbpedia.org/resource/Southeast_Asia",
#       "text": "Southeast Asia"
#     },
#     {
#       "relevance": 0.833651,
#       "dbpedia_resource": "http://dbpedia.org/resource/Indo-Pakistani_War_of_1965",
#       "text": "Indo-Pakistani War of 1965"
#     },
#     {
#       "relevance": 0.815174,
#       "dbpedia_resource": "http://dbpedia.org/resource/Army",
#       "text": "Army"
#     },
#     {
#       "relevance": 0.812532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Burma",
#       "text": "Burma"
#     },
#     {
#       "relevance": 0.792386,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hero",
#       "text": "Hero"
#     },
#     {
#       "relevance": 0.772829,
#       "dbpedia_resource": "http://dbpedia.org/resource/India",
#       "text": "India"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 625
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.910726,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.821444,
#       "dbpedia_resource": "http://dbpedia.org/resource/Poison",
#       "text": "Poison"
#     },
#     {
#       "relevance": 0.578001,
#       "dbpedia_resource": "http://dbpedia.org/resource/Girl",
#       "text": "Girl"
#     },
#     {
#       "relevance": 0.535064,
#       "dbpedia_resource": "http://dbpedia.org/resource/Boy",
#       "text": "Boy"
#     },
#     {
#       "relevance": 0.534498,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mind",
#       "text": "Mind"
#     },
#     {
#       "relevance": 0.505242,
#       "dbpedia_resource": "http://dbpedia.org/resource/Consciousness",
#       "text": "Consciousness"
#     },
#     {
#       "relevance": 0.504287,
#       "dbpedia_resource": "http://dbpedia.org/resource/Man",
#       "text": "Man"
#     },
#     {
#       "relevance": 0.504103,
#       "dbpedia_resource": "http://dbpedia.org/resource/Term_(time)",
#       "text": "Term"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1666
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.892377,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.89197,
#       "dbpedia_resource": "http://dbpedia.org/resource/Theft",
#       "text": "Theft"
#     },
#     {
#       "relevance": 0.811883,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.746705,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.745509,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mumbai",
#       "text": "Mumbai"
#     },
#     {
#       "relevance": 0.743313,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.742227,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Real",
#       "text": "The Real"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3362
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.983952,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.860773,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.73958,
#       "dbpedia_resource": "http://dbpedia.org/resource/Physician",
#       "text": "Physician"
#     },
#     {
#       "relevance": 0.63623,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     },
#     {
#       "relevance": 0.567451,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.556409,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.536928,
#       "dbpedia_resource": "http://dbpedia.org/resource/Medicine",
#       "text": "Medicine"
#     },
#     {
#       "relevance": 0.438196,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shekhar_Kapur",
#       "text": "Shekhar Kapur"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2143
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.927854,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.913135,
#       "dbpedia_resource": "http://dbpedia.org/resource/Theft",
#       "text": "Theft"
#     },
#     {
#       "relevance": 0.837631,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.80607,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.681094,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.642317,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automobile",
#       "text": "Automobile"
#     },
#     {
#       "relevance": 0.627019,
#       "dbpedia_resource": "http://dbpedia.org/resource/Looting",
#       "text": "Looting"
#     },
#     {
#       "relevance": 0.615532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3277
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.919098,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz",
#       "text": "Mercedes-Benz"
#     },
#     {
#       "relevance": 0.723159,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stirling_Moss",
#       "text": "Stirling Moss"
#     },
#     {
#       "relevance": 0.707598,
#       "dbpedia_resource": "http://dbpedia.org/resource/Want",
#       "text": "Want"
#     },
#     {
#       "relevance": 0.685525,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daimler_AG",
#       "text": "Daimler AG"
#     },
#     {
#       "relevance": 0.682582,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mika_H\u00e4kkinen",
#       "text": "Mika H\u00e4kkinen"
#     },
#     {
#       "relevance": 0.669836,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-AMG",
#       "text": "Mercedes-AMG"
#     },
#     {
#       "relevance": 0.66943,
#       "dbpedia_resource": "http://dbpedia.org/resource/Karl_Benz",
#       "text": "Karl Benz"
#     },
#     {
#       "relevance": 0.661751,
#       "dbpedia_resource": "http://dbpedia.org/resource/Formula_One",
#       "text": "Formula One"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1117
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.921384,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.854413,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.743532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Romance_(love)",
#       "text": "Romance"
#     },
#     {
#       "relevance": 0.667838,
#       "dbpedia_resource": "http://dbpedia.org/resource/2003_in_film",
#       "text": "2003 in film"
#     },
#     {
#       "relevance": 0.662442,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.614421,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lust",
#       "text": "Lust"
#     },
#     {
#       "relevance": 0.611336,
#       "dbpedia_resource": "http://dbpedia.org/resource/Billy_Corgan",
#       "text": "Billy Corgan"
#     },
#     {
#       "relevance": 0.5874,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 530
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.984419,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.856824,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.768495,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.743123,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.517733,
#       "dbpedia_resource": "http://dbpedia.org/resource/Proposal_of_marriage",
#       "text": "Proposal of marriage"
#     },
#     {
#       "relevance": 0.515028,
#       "dbpedia_resource": "http://dbpedia.org/resource/Alimony",
#       "text": "Alimony"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1520
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.988228,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.700269,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.636583,
#       "dbpedia_resource": "http://dbpedia.org/resource/Doctor_Who",
#       "text": "Doctor Who"
#     },
#     {
#       "relevance": 0.619782,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.595393,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Five_Doctors",
#       "text": "The Five Doctors"
#     },
#     {
#       "relevance": 0.577806,
#       "dbpedia_resource": "http://dbpedia.org/resource/Master_(Doctor_Who)",
#       "text": "Master"
#     },
#     {
#       "relevance": 0.573813,
#       "dbpedia_resource": "http://dbpedia.org/resource/Third_Doctor",
#       "text": "Third Doctor"
#     },
#     {
#       "relevance": 0.570482,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Christmas_Invasion",
#       "text": "The Christmas Invasion"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3457
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.913469,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.812904,
#       "dbpedia_resource": "http://dbpedia.org/resource/Poverty",
#       "text": "Poverty"
#     },
#     {
#       "relevance": 0.808302,
#       "dbpedia_resource": "http://dbpedia.org/resource/Oncology",
#       "text": "Oncology"
#     },
#     {
#       "relevance": 0.708283,
#       "dbpedia_resource": "http://dbpedia.org/resource/Cancer",
#       "text": "Cancer"
#     },
#     {
#       "relevance": 0.657557,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illness",
#       "text": "Illness"
#     },
#     {
#       "relevance": 0.646073,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chemotherapy",
#       "text": "Chemotherapy"
#     },
#     {
#       "relevance": 0.642363,
#       "dbpedia_resource": "http://dbpedia.org/resource/Treats",
#       "text": "Treats"
#     },
#     {
#       "relevance": 0.61478,
#       "dbpedia_resource": "http://dbpedia.org/resource/Imaginary_(sociology)",
#       "text": "Imaginary"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1863
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.919653,
#       "dbpedia_resource": "http://dbpedia.org/resource/Death",
#       "text": "Death"
#     },
#     {
#       "relevance": 0.90459,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hema_Malini",
#       "text": "Hema Malini"
#     },
#     {
#       "relevance": 0.895911,
#       "dbpedia_resource": "http://dbpedia.org/resource/Indian_film_actors",
#       "text": "Indian film actors"
#     },
#     {
#       "relevance": 0.88803,
#       "dbpedia_resource": "http://dbpedia.org/resource/Rajesh_Khanna",
#       "text": "Rajesh Khanna"
#     },
#     {
#       "relevance": 0.875229,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shammi_Kapoor",
#       "text": "Shammi Kapoor"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1056
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.912942,
#       "dbpedia_resource": "http://dbpedia.org/resource/Termination_of_employment",
#       "text": "Termination of employment"
#     },
#     {
#       "relevance": 0.895778,
#       "dbpedia_resource": "http://dbpedia.org/resource/Time",
#       "text": "Time"
#     },
#     {
#       "relevance": 0.881107,
#       "dbpedia_resource": "http://dbpedia.org/resource/Present",
#       "text": "Present"
#     },
#     {
#       "relevance": 0.815816,
#       "dbpedia_resource": "http://dbpedia.org/resource/Resignation",
#       "text": "Resignation"
#     },
#     {
#       "relevance": 0.815339,
#       "dbpedia_resource": "http://dbpedia.org/resource/Tell",
#       "text": "Tell"
#     },
#     {
#       "relevance": 0.776021,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1410
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.97906,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.838057,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.835627,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.748564,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.734712,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 952
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.916093,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.68769,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.661504,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.632706,
#       "dbpedia_resource": "http://dbpedia.org/resource/American_novels",
#       "text": "American novels"
#     },
#     {
#       "relevance": 0.59947,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daughter",
#       "text": "Daughter"
#     },
#     {
#       "relevance": 0.5874,
#       "dbpedia_resource": "http://dbpedia.org/resource/Millionaire",
#       "text": "Millionaire"
#     },
#     {
#       "relevance": 0.585984,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Guardian",
#       "text": "The Guardian"
#     },
#     {
#       "relevance": 0.583758,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Help",
#       "text": "The Help"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 743
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.907938,
#       "dbpedia_resource": "http://dbpedia.org/resource/Toronto_International_Film_Festival",
#       "text": "Toronto International Film Festival"
#     },
#     {
#       "relevance": 0.85974,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Hanging_Garden",
#       "text": "The Hanging Garden"
#     },
#     {
#       "relevance": 0.8211,
#       "dbpedia_resource": "http://dbpedia.org/resource/Apartment",
#       "text": "Apartment"
#     },
#     {
#       "relevance": 0.811779,
#       "dbpedia_resource": "http://dbpedia.org/resource/Garden",
#       "text": "Garden"
#     },
#     {
#       "relevance": 0.787661,
#       "dbpedia_resource": "http://dbpedia.org/resource/Renting",
#       "text": "Renting"
#     },
#     {
#       "relevance": 0.783044,
#       "dbpedia_resource": "http://dbpedia.org/resource/BAFTA_Award_for_Best_Film",
#       "text": "BAFTA Award for Best Film"
#     },
#     {
#       "relevance": 0.78246,
#       "dbpedia_resource": "http://dbpedia.org/resource/Thom_Fitzgerald",
#       "text": "Thom Fitzgerald"
#     },
#     {
#       "relevance": 0.773139,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chris_Leavins",
#       "text": "Chris Leavins"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 512
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.911877,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.8188,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mohandas_Karamchand_Gandhi",
#       "text": "Mohandas Karamchand Gandhi"
#     },
#     {
#       "relevance": 0.792379,
#       "dbpedia_resource": "http://dbpedia.org/resource/Truth",
#       "text": "Truth"
#     },
#     {
#       "relevance": 0.791206,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 943
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.970475,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.812451,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.552699,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.546322,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.534002,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stepfamily",
#       "text": "Stepfamily"
#     },
#     {
#       "relevance": 0.471133,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.454207,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.447092,
#       "dbpedia_resource": "http://dbpedia.org/resource/Romance_(love)",
#       "text": "Romance"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 4569
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.964151,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.557196,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.528011,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illness",
#       "text": "Illness"
#     },
#     {
#       "relevance": 0.52435,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stay",
#       "text": "Stay"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1772
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.972027,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.605709,
#       "dbpedia_resource": "http://dbpedia.org/resource/Water",
#       "text": "Water"
#     },
#     {
#       "relevance": 0.590461,
#       "dbpedia_resource": "http://dbpedia.org/resource/Village_(disambiguation)",
#       "text": "Village"
#     },
#     {
#       "relevance": 0.557075,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arid",
#       "text": "Arid"
#     },
#     {
#       "relevance": 0.518154,
#       "dbpedia_resource": "http://dbpedia.org/resource/Villager_(disambiguation)",
#       "text": "Villager"
#     },
#     {
#       "relevance": 0.514293,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.474269,
#       "dbpedia_resource": "http://dbpedia.org/resource/Precipitation_(meteorology)",
#       "text": "Precipitation"
#     },
#     {
#       "relevance": 0.46615,
#       "dbpedia_resource": "http://dbpedia.org/resource/Surface_runoff",
#       "text": "Surface runoff"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 477
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.94596,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.762857,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.733784,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.729745,
#       "dbpedia_resource": "http://dbpedia.org/resource/Constable",
#       "text": "Constable"
#     },
#     {
#       "relevance": 0.63994,
#       "dbpedia_resource": "http://dbpedia.org/resource/Twist",
#       "text": "Twist"
#     },
#     {
#       "relevance": 0.624213,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.623261,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life_imprisonment",
#       "text": "Life imprisonment"
#     },
#     {
#       "relevance": 0.586417,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminal_justice",
#       "text": "Criminal justice"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3714
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.920687,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.728868,
#       "dbpedia_resource": "http://dbpedia.org/resource/Celibacy",
#       "text": "Celibacy"
#     },
#     {
#       "relevance": 0.718031,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.561,
#       "dbpedia_resource": "http://dbpedia.org/resource/Clerical_celibacy",
#       "text": "Clerical celibacy"
#     },
#     {
#       "relevance": 0.559968,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 761
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.894026,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.893535,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automobile",
#       "text": "Automobile"
#     },
#     {
#       "relevance": 0.890717,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suspect",
#       "text": "Suspect"
#     },
#     {
#       "relevance": 0.886784,
#       "dbpedia_resource": "http://dbpedia.org/resource/Piano",
#       "text": "Piano"
#     },
#     {
#       "relevance": 0.882156,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.841516,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2049
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.971182,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.831818,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.738595,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illegal_drug_trade",
#       "text": "Illegal drug trade"
#     },
#     {
#       "relevance": 0.67679,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illegal_immigration",
#       "text": "Illegal immigration"
#     },
#     {
#       "relevance": 0.67221,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminology",
#       "text": "Criminology"
#     },
#     {
#       "relevance": 0.641441,
#       "dbpedia_resource": "http://dbpedia.org/resource/Los_Angeles",
#       "text": "Los Angeles"
#     },
#     {
#       "relevance": 0.587957,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.561532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Organized_crime",
#       "text": "Organized crime"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1375
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.944702,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.883341,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.847301,
#       "dbpedia_resource": "http://dbpedia.org/resource/Film",
#       "text": "Film"
#     },
#     {
#       "relevance": 0.81055,
#       "dbpedia_resource": "http://dbpedia.org/resource/Reality",
#       "text": "Reality"
#     },
#     {
#       "relevance": 0.792602,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Real_World",
#       "text": "The Real World"
#     },
#     {
#       "relevance": 0.71701,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.683322,
#       "dbpedia_resource": "http://dbpedia.org/resource/Core_issues_in_ethics",
#       "text": "Core issues in ethics"
#     },
#     {
#       "relevance": 0.67509,
#       "dbpedia_resource": "http://dbpedia.org/resource/MTV",
#       "text": "MTV"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1079
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.937232,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lion",
#       "text": "Lion"
#     },
#     {
#       "relevance": 0.892622,
#       "dbpedia_resource": "http://dbpedia.org/resource/Haathi_Mere_Saathi",
#       "text": "Haathi Mere Saathi"
#     },
#     {
#       "relevance": 0.844019,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.795083,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.770597,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.642474,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wildlife",
#       "text": "Wildlife"
#     },
#     {
#       "relevance": 0.625575,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Animals",
#       "text": "The Animals"
#     },
#     {
#       "relevance": 0.611871,
#       "dbpedia_resource": "http://dbpedia.org/resource/Tiger",
#       "text": "Tiger"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1060
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.954282,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.763222,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.756604,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.664038,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.659557,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     },
#     {
#       "relevance": 0.646717,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.583586,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.560559,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3649
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.943285,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.709682,
#       "dbpedia_resource": "http://dbpedia.org/resource/Jury",
#       "text": "Jury"
#     },
#     {
#       "relevance": 0.698699,
#       "dbpedia_resource": "http://dbpedia.org/resource/Judge",
#       "text": "Judge"
#     },
#     {
#       "relevance": 0.544387,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lawyer",
#       "text": "Lawyer"
#     },
#     {
#       "relevance": 0.513255,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.499748,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.439948,
#       "dbpedia_resource": "http://dbpedia.org/resource/Prosecutor",
#       "text": "Prosecutor"
#     },
#     {
#       "relevance": 0.4343,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     }
#   ],
# ...
#       "text": "Pregnancy"
#     },
#     {
#       "relevance": 0.342543,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 4270
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.96869,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.670273,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_note",
#       "text": "Suicide note"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 5595
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.974668,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.464806,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.394445,
#       "dbpedia_resource": "http://dbpedia.org/resource/Son",
#       "text": "Son"
#     },
#     {
#       "relevance": 0.394135,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stepfamily",
#       "text": "Stepfamily"
#     },
#     {
#       "relevance": 0.355201,
#       "dbpedia_resource": "http://dbpedia.org/resource/Man",
#       "text": "Man"
#     },
#     {
#       "relevance": 0.352083,
#       "dbpedia_resource": "http://dbpedia.org/resource/Who_Wants_to_Be_a_Millionaire?",
#       "text": "Who Wants to Be a Millionaire?"
#     },
#     {
#       "relevance": 0.346594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1140
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.949597,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illegal_drug_trade",
#       "text": "Illegal drug trade"
#     },
#     {
#       "relevance": 0.776779,
#       "dbpedia_resource": "http://dbpedia.org/resource/Heroin",
#       "text": "Heroin"
#     },
#     {
#       "relevance": 0.76102,
#       "dbpedia_resource": "http://dbpedia.org/resource/Murder",
#       "text": "Murder"
#     },
#     {
#       "relevance": 0.702058,
#       "dbpedia_resource": "http://dbpedia.org/resource/Drug",
#       "text": "Drug"
#     },
#     {
#       "relevance": 0.655534,
#       "dbpedia_resource": "http://dbpedia.org/resource/Indian_film_actors",
#       "text": "Indian film actors"
#     },
#     {
#       "relevance": 0.642891,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.639884,
#       "dbpedia_resource": "http://dbpedia.org/resource/Indian_actors",
#       "text": "Indian actors"
#     },
#     {
#       "relevance": 0.586684,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life_imprisonment",
#       "text": "Life imprisonment"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1463
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.900641,
#       "dbpedia_resource": "http://dbpedia.org/resource/Essence",
#       "text": "Essence"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 106
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.922342,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.644805,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Run",
#       "text": "The Run"
#     },
#     {
#       "relevance": 0.633827,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hinduism",
#       "text": "Hinduism"
#     },
#     {
#       "relevance": 0.611398,
#       "dbpedia_resource": "http://dbpedia.org/resource/Prison",
#       "text": "Prison"
#     },
#     {
#       "relevance": 0.583814,
#       "dbpedia_resource": "http://dbpedia.org/resource/Doubt",
#       "text": "Doubt"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1398
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.948048,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.803153,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wedding",
#       "text": "Wedding"
#     },
#     {
#       "relevance": 0.684355,
#       "dbpedia_resource": "http://dbpedia.org/resource/Holi",
#       "text": "Holi"
#     },
#     {
#       "relevance": 0.642505,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.489439,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.484991,
#       "dbpedia_resource": "http://dbpedia.org/resource/Engagement",
#       "text": "Engagement"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2134
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.955339,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.42735,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.42305,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.384075,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.353014,
#       "dbpedia_resource": "http://dbpedia.org/resource/Truth",
#       "text": "Truth"
#     },
#     {
#       "relevance": 0.310081,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nuclear_family",
#       "text": "Nuclear family"
#     },
#     {
#       "relevance": 0.292123,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.288242,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stepfamily",
#       "text": "Stepfamily"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1207
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.897406,
#       "dbpedia_resource": "http://dbpedia.org/resource/War_(disambiguation)",
#       "text": "War"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 196
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.906977,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.893918,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.801708,
#       "dbpedia_resource": "http://dbpedia.org/resource/University",
#       "text": "University"
#     },
#     {
#       "relevance": 0.760731,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suspect",
#       "text": "Suspect"
#     },
#     {
#       "relevance": 0.760174,
#       "dbpedia_resource": "http://dbpedia.org/resource/Affair",
#       "text": "Affair"
#     },
#     {
#       "relevance": 0.759232,
#       "dbpedia_resource": "http://dbpedia.org/resource/Professor",
#       "text": "Professor"
#     },
#     {
#       "relevance": 0.758115,
#       "dbpedia_resource": "http://dbpedia.org/resource/Truth",
#       "text": "Truth"
#     },
#     {
#       "relevance": 0.70534,
#       "dbpedia_resource": "http://dbpedia.org/resource/Education",
#       "text": "Education"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 907
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.934292,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.901398,
#       "dbpedia_resource": "http://dbpedia.org/resource/Amitabh_Bachchan",
#       "text": "Amitabh Bachchan"
#     },
#     {
#       "relevance": 0.805762,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminal_law",
#       "text": "Criminal law"
#     },
#     {
#       "relevance": 0.76122,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hinduism",
#       "text": "Hinduism"
#     },
#     {
#       "relevance": 0.7476,
#       "dbpedia_resource": "http://dbpedia.org/resource/Underworld",
#       "text": "Underworld"
#     },
#     {
#       "relevance": 0.72744,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.686878,
#       "dbpedia_resource": "http://dbpedia.org/resource/Bollywood",
#       "text": "Bollywood"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 421
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.946225,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.903753,
#       "dbpedia_resource": "http://dbpedia.org/resource/Question",
#       "text": "Question"
#     },
#     {
#       "relevance": 0.831268,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriageable_age",
#       "text": "Marriageable age"
#     },
#     {
#       "relevance": 0.760954,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interrogative_word",
#       "text": "Interrogative word"
#     },
#     {
#       "relevance": 0.735345,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.713632,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.699306,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sentence_(linguistics)",
#       "text": "Sentence"
#     },
#     {
#       "relevance": 0.623301,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nuclear_weapon",
#       "text": "Nuclear weapon"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1383
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.885494,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mystery_fiction",
#       "text": "Mystery fiction"
#     },
#     {
#       "relevance": 0.882832,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime_fiction",
#       "text": "Crime fiction"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 322
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.953396,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.858289,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.45034,
#       "dbpedia_resource": "http://dbpedia.org/resource/Maya_&_Miguel",
#       "text": "Maya & Miguel"
#     },
#     {
#       "relevance": 0.448163,
#       "dbpedia_resource": "http://dbpedia.org/resource/Engagement",
#       "text": "Engagement"
#     },
#     {
#       "relevance": 0.435586,
#       "dbpedia_resource": "http://dbpedia.org/resource/Carnival",
#       "text": "Carnival"
#     },
#     {
#       "relevance": 0.427923,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arranged_marriage",
#       "text": "Arranged marriage"
#     },
#     {
#       "relevance": 0.425441,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.420298,
#       "dbpedia_resource": "http://dbpedia.org/resource/Romance_(love)",
#       "text": "Romance"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2851
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.968448,
#       "dbpedia_resource": "http://dbpedia.org/resource/Prison",
#       "text": "Prison"
#     },
#     {
#       "relevance": 0.84105,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.711469,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sentence_(law)",
#       "text": "Sentence"
#     },
#     {
#       "relevance": 0.676428,
#       "dbpedia_resource": "http://dbpedia.org/resource/Collateral_consequences_of_criminal_charges",
#       "text": "Collateral consequences of criminal charges"
#     },
#     {
#       "relevance": 0.650864,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.635557,
#       "dbpedia_resource": "http://dbpedia.org/resource/Penology",
#       "text": "Penology"
#     },
#     {
#       "relevance": 0.633316,
#       "dbpedia_resource": "http://dbpedia.org/resource/Law",
#       "text": "Law"
#     },
#     {
#       "relevance": 0.585382,
#       "dbpedia_resource": "http://dbpedia.org/resource/Deconstruction_(building)",
#       "text": "Deconstruction"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1181
#   },
#   "language": "en"
# }
# {
#   "concepts": [
#     {
#       "relevance": 0.980518,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.669357,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.63825,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     },
#     {
#       "relevance": 0.59681,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.595408,
#       "dbpedia_resource": "http://dbpedia.org/resource/Core_issues_in_ethics",
#       "text": "Core issues in ethics"
#     },
#     {
#       "relevance": 0.549984,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     },
#     {
#       "relevance": 0.543246,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suffering",
#       "text": "Suffering"
#     },
#     {
#       "relevance": 0.53361,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 766
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.948245,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.67188,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.667587,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.603086,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sting_(musician)",
#       "text": "Sting"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2447
#   },
#   "language": "en"
# }
#
#
# {
#   "concepts": [
#     {
#       "relevance": 0.937998,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nanny",
#       "text": "Nanny"
#     },
#     {
#       "relevance": 0.890328,
#       "dbpedia_resource": "http://dbpedia.org/resource/Domestic_worker",
#       "text": "Domestic worker"
#     },
#     {
#       "relevance": 0.859128,
#       "dbpedia_resource": "http://dbpedia.org/resource/Maid",
#       "text": "Maid"
#     },
#     {
#       "relevance": 0.832229,
#       "dbpedia_resource": "http://dbpedia.org/resource/Spirit",
#       "text": "Spirit"
#     },
#     {
#       "relevance": 0.831616,
#       "dbpedia_resource": "http://dbpedia.org/resource/Supernatural",
#       "text": "Supernatural"
#     },
#     {
#       "relevance": 0.800551,
#       "dbpedia_resource": "http://dbpedia.org/resource/Butler",
#       "text": "Butler"
#     },
#     {
#       "relevance": 0.743278,
#       "dbpedia_resource": "http://dbpedia.org/resource/Paranormal",
#       "text": "Paranormal"
#     },
#     {
#       "relevance": 0.693459,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     }
#   ],
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 716
#   },
#   "language": "en"
# }

# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
import Features, EntitiesOptions, KeywordsOptions ,ConceptsOptions
import pandas
from operator import itemgetter
def Sort(sub_li): 
    l = len(sub_li) 
    for i in range(0, l): 
        for j in range(0, l-i-1): 
            if (sub_li[j][0] > sub_li[j + 1][0]): 
                tempo = sub_li[j] 
                sub_li[j]= sub_li[j + 1] 
                sub_li[j + 1]= tempo 
    return sub_li
o = input("enter number(0-132)")   
flag = {}
xyz = {}
for j in range(0,k):

    flag[j]=0.0 
    h=response[j]
    for m in range(0,len(response[int(o)]["concepts"])):
        for n in range(0,len(h["concepts"])):
            if(response[int(o)]["concepts"][m]["text"]==h["concepts"][n]["text"]):
                    flag[j]=flag[j]+response[0]["concepts"][m]["relevance"]+response[j]["concepts"][n]["relevance"]

for j in range(0,k):
    xyz[j] = (flag[j],x[j])
h = Sort(xyz)
for j in range(0,10):
    print(h[j][1])
# Out:
# enter number(0-132)9
# Geet
# Humjoli
# Jeevan Mrityu
# Mere Humsafar
# Rootha Na Karo
# Sachaa Jhutha
# Tum Haseen Main Jawaan
# Aap Aye Bahaar Ayee
# Andaz
# Anubhav

# %%
print(k)

# %%
print(df["Movie Name"][2100])
# Out:
# Raftaar

# %%
t=df.groupby("Movie Name")
print(t)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x00000179A8A26F28>
