# %%
#get the data
#summaries take fron coref plot

import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
import Features, EntitiesOptions, KeywordsOptions ,ConceptsOptions
import pandas
abc = ""
response = {}
x = {}
k = 0
df = pandas.read_csv('coref_plot.csv')
y = df["Movie Name"][0]
for i  in range(0,5000):
    x[k] = df["Movie Name"][i]
    if x[k]==y:
        abc = abc +df["Coref Plot"][i]
    else:
        if(abc):
            print("\n")
        
            natural_language_understanding = NaturalLanguageUnderstandingV1(
              username='06320980-d791-4920-834b-3c5368522608',
              password='UKVXqFnwnNnZ',
              version='2018-03-16',
            )
            response[k] = natural_language_understanding.analyze(
              text=abc
        ,
          features=Features(
        concepts=ConceptsOptions(
              limit=8),
          )).get_result()
            print(json.dumps(response[k], indent=2))
        k=k+1
        y=x[k-1]
        abc=""
# Out:
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 993
#   },
#   "concepts": [
#     {
#       "relevance": 0.98703,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.643126,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.585549,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.549378,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.548032,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.520734,
#       "dbpedia_resource": "http://dbpedia.org/resource/Black-and-white_films",
#       "text": "Black-and-white films"
#     },
#     {
#       "relevance": 0.46901,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mansion",
#       "text": "Mansion"
#     },
#     {
#       "relevance": 0.464702,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inheritance",
#       "text": "Inheritance"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 677
#   },
#   "concepts": [
#     {
#       "relevance": 0.954234,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1272
#   },
#   "concepts": [
#     {
#       "relevance": 0.909462,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.778111,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.642639,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.619604,
#       "dbpedia_resource": "http://dbpedia.org/resource/Initiative",
#       "text": "Initiative"
#     },
#     {
#       "relevance": 0.569686,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.560287,
#       "dbpedia_resource": "http://dbpedia.org/resource/Killer",
#       "text": "Killer"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 183
#   },
#   "concepts": [
#     {
#       "relevance": 0.930018,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.684092,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.680379,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1180
#   },
#   "concepts": [
#     {
#       "relevance": 0.959123,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.635762,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.610923,
#       "dbpedia_resource": "http://dbpedia.org/resource/Proposal",
#       "text": "Proposal"
#     },
#     {
#       "relevance": 0.527838,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.466858,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.457401,
#       "dbpedia_resource": "http://dbpedia.org/resource/Proposals_(play)",
#       "text": "Proposals"
#     },
#     {
#       "relevance": 0.415577,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.413973,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 812
#   },
#   "concepts": [
#     {
#       "relevance": 0.908364,
#       "dbpedia_resource": "http://dbpedia.org/resource/Higher_education",
#       "text": "Higher education"
#     },
#     {
#       "relevance": 0.90023,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.813147,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Help",
#       "text": "The Help"
#     },
#     {
#       "relevance": 0.79672,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.781682,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inspector",
#       "text": "Inspector"
#     },
#     {
#       "relevance": 0.773888,
#       "dbpedia_resource": "http://dbpedia.org/resource/Education",
#       "text": "Education"
#     },
#     {
#       "relevance": 0.760878,
#       "dbpedia_resource": "http://dbpedia.org/resource/Planning",
#       "text": "Planning"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2670
#   },
#   "concepts": [
#     {
#       "relevance": 0.926865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.846864,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.677663,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.654494,
#       "dbpedia_resource": "http://dbpedia.org/resource/India",
#       "text": "India"
#     },
#     {
#       "relevance": 0.578706,
#       "dbpedia_resource": "http://dbpedia.org/resource/Who_Wants_to_Be_a_Millionaire?",
#       "text": "Who Wants to Be a Millionaire?"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 617
#   },
#   "concepts": [
#     {
#       "relevance": 0.926012,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.631003,
#       "dbpedia_resource": "http://dbpedia.org/resource/Cleveland_Indians",
#       "text": "Cleveland Indians"
#     },
#     {
#       "relevance": 0.6141,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Trio",
#       "text": "The Trio"
#     },
#     {
#       "relevance": 0.575,
#       "dbpedia_resource": "http://dbpedia.org/resource/Employment",
#       "text": "Employment"
#     },
#     {
#       "relevance": 0.5589,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wage",
#       "text": "Wage"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1296
#   },
#   "concepts": [
#     {
#       "relevance": 0.945554,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.763037,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.709981,
#       "dbpedia_resource": "http://dbpedia.org/resource/Inspector",
#       "text": "Inspector"
#     },
#     {
#       "relevance": 0.680891,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police_station",
#       "text": "Police station"
#     },
#     {
#       "relevance": 0.678699,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sub-Inspector",
#       "text": "Sub-Inspector"
#     },
#     {
#       "relevance": 0.634646,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.576097,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sting_(musician)",
#       "text": "Sting"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 609
#   },
#   "concepts": [
#     {
#       "relevance": 0.946549,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.548414,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.537888,
#       "dbpedia_resource": "http://dbpedia.org/resource/Demography",
#       "text": "Demography"
#     },
#     {
#       "relevance": 0.456409,
#       "dbpedia_resource": "http://dbpedia.org/resource/Kinship",
#       "text": "Kinship"
#     },
#     {
#       "relevance": 0.439609,
#       "dbpedia_resource": "http://dbpedia.org/resource/Miscegenation",
#       "text": "Miscegenation"
#     },
#     {
#       "relevance": 0.438061,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life",
#       "text": "Life"
#     },
#     {
#       "relevance": 0.415411,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arranged_marriage",
#       "text": "Arranged marriage"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 756
#   },
#   "concepts": [
#     {
#       "relevance": 0.972788,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.575136,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.566467,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love_letter",
#       "text": "Love letter"
#     },
#     {
#       "relevance": 0.526582,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hinduism",
#       "text": "Hinduism"
#     },
#     {
#       "relevance": 0.492175,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.481594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.474765,
#       "dbpedia_resource": "http://dbpedia.org/resource/Devi",
#       "text": "Devi"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 654
#   },
#   "concepts": [
#     {
#       "relevance": 0.903719,
#       "dbpedia_resource": "http://dbpedia.org/resource/Psychological_abuse",
#       "text": "Psychological abuse"
#     },
#     {
#       "relevance": 0.875731,
#       "dbpedia_resource": "http://dbpedia.org/resource/Victim",
#       "text": "Victim"
#     },
#     {
#       "relevance": 0.850035,
#       "dbpedia_resource": "http://dbpedia.org/resource/Oppression",
#       "text": "Oppression"
#     },
#     {
#       "relevance": 0.840096,
#       "dbpedia_resource": "http://dbpedia.org/resource/Core_issues_in_ethics",
#       "text": "Core issues in ethics"
#     },
#     {
#       "relevance": 0.836371,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Victim_(novel)",
#       "text": "The Victim"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 576
#   },
#   "concepts": [
#     {
#       "relevance": 0.894132,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.783167,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.761687,
#       "dbpedia_resource": "http://dbpedia.org/resource/Identity_theft",
#       "text": "Identity theft"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2695
#   },
#   "concepts": [
#     {
#       "relevance": 0.898928,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.795386,
#       "dbpedia_resource": "http://dbpedia.org/resource/Truth",
#       "text": "Truth"
#     },
#     {
#       "relevance": 0.793059,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life",
#       "text": "Life"
#     },
#     {
#       "relevance": 0.773487,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.708297,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother-in-law",
#       "text": "Mother-in-law"
#     },
#     {
#       "relevance": 0.67392,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1638
#   },
#   "concepts": [
#     {
#       "relevance": 0.930166,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.781793,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.771917,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.703237,
#       "dbpedia_resource": "http://dbpedia.org/resource/Better",
#       "text": "Better"
#     },
#     {
#       "relevance": 0.650354,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.558232,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mental_disorder",
#       "text": "Mental disorder"
#     },
#     {
#       "relevance": 0.556972,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shock",
#       "text": "Shock"
#     },
#     {
#       "relevance": 0.556669,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Terrace",
#       "text": "The Terrace"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2111
#   },
#   "concepts": [
#     {
#       "relevance": 0.96148,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.558526,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.453614,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.435505,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.416118,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.385468,
#       "dbpedia_resource": "http://dbpedia.org/resource/Son",
#       "text": "Son"
#     },
#     {
#       "relevance": 0.362452,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.360787,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daughter",
#       "text": "Daughter"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 89
#   },
#   "concepts": [],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1169
#   },
#   "concepts": [
#     {
#       "relevance": 0.977804,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.804504,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.710628,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.685873,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.672215,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.579733,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     },
#     {
#       "relevance": 0.577556,
#       "dbpedia_resource": "http://dbpedia.org/resource/Actor",
#       "text": "Actor"
#     },
#     {
#       "relevance": 0.562179,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1244
#   },
#   "concepts": [
#     {
#       "relevance": 0.941334,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.75002,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.707215,
#       "dbpedia_resource": "http://dbpedia.org/resource/Singing",
#       "text": "Singing"
#     },
#     {
#       "relevance": 0.66525,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.663118,
#       "dbpedia_resource": "http://dbpedia.org/resource/Insane_Clown_Posse",
#       "text": "Insane Clown Posse"
#     },
#     {
#       "relevance": 0.6141,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Asylum",
#       "text": "The Asylum"
#     },
#     {
#       "relevance": 0.613347,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gallows",
#       "text": "Gallows"
#     },
#     {
#       "relevance": 0.611524,
#       "dbpedia_resource": "http://dbpedia.org/resource/Insanity",
#       "text": "Insanity"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1627
#   },
#   "concepts": [
#     {
#       "relevance": 0.962982,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.674789,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.604719,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daughter",
#       "text": "Daughter"
#     },
#     {
#       "relevance": 0.565573,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.542862,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     },
#     {
#       "relevance": 0.542566,
#       "dbpedia_resource": "http://dbpedia.org/resource/Money",
#       "text": "Money"
#     },
#     {
#       "relevance": 0.524293,
#       "dbpedia_resource": "http://dbpedia.org/resource/Son",
#       "text": "Son"
#     },
#     {
#       "relevance": 0.406686,
#       "dbpedia_resource": "http://dbpedia.org/resource/Employment",
#       "text": "Employment"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 625
#   },
#   "concepts": [
#     {
#       "relevance": 0.919916,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.893348,
#       "dbpedia_resource": "http://dbpedia.org/resource/Black-and-white_films",
#       "text": "Black-and-white films"
#     },
#     {
#       "relevance": 0.840584,
#       "dbpedia_resource": "http://dbpedia.org/resource/Southeast_Asia",
#       "text": "Southeast Asia"
#     },
#     {
#       "relevance": 0.833651,
#       "dbpedia_resource": "http://dbpedia.org/resource/Indo-Pakistani_War_of_1965",
#       "text": "Indo-Pakistani War of 1965"
#     },
#     {
#       "relevance": 0.815174,
#       "dbpedia_resource": "http://dbpedia.org/resource/Army",
#       "text": "Army"
#     },
#     {
#       "relevance": 0.812532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Burma",
#       "text": "Burma"
#     },
#     {
#       "relevance": 0.792386,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hero",
#       "text": "Hero"
#     },
#     {
#       "relevance": 0.772829,
#       "dbpedia_resource": "http://dbpedia.org/resource/India",
#       "text": "India"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1666
#   },
#   "concepts": [
#     {
#       "relevance": 0.910726,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.821444,
#       "dbpedia_resource": "http://dbpedia.org/resource/Poison",
#       "text": "Poison"
#     },
#     {
#       "relevance": 0.578001,
#       "dbpedia_resource": "http://dbpedia.org/resource/Girl",
#       "text": "Girl"
#     },
#     {
#       "relevance": 0.535064,
#       "dbpedia_resource": "http://dbpedia.org/resource/Boy",
#       "text": "Boy"
#     },
#     {
#       "relevance": 0.534498,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mind",
#       "text": "Mind"
#     },
#     {
#       "relevance": 0.505242,
#       "dbpedia_resource": "http://dbpedia.org/resource/Consciousness",
#       "text": "Consciousness"
#     },
#     {
#       "relevance": 0.504287,
#       "dbpedia_resource": "http://dbpedia.org/resource/Man",
#       "text": "Man"
#     },
#     {
#       "relevance": 0.504103,
#       "dbpedia_resource": "http://dbpedia.org/resource/Term_(time)",
#       "text": "Term"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3362
#   },
#   "concepts": [
#     {
#       "relevance": 0.892377,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.89197,
#       "dbpedia_resource": "http://dbpedia.org/resource/Theft",
#       "text": "Theft"
#     },
#     {
#       "relevance": 0.811883,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.746705,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.745509,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mumbai",
#       "text": "Mumbai"
#     },
#     {
#       "relevance": 0.743313,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.742227,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Real",
#       "text": "The Real"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2143
#   },
#   "concepts": [
#     {
#       "relevance": 0.983952,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.860773,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.73958,
#       "dbpedia_resource": "http://dbpedia.org/resource/Physician",
#       "text": "Physician"
#     },
#     {
#       "relevance": 0.63623,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     },
#     {
#       "relevance": 0.567451,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.556409,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.536928,
#       "dbpedia_resource": "http://dbpedia.org/resource/Medicine",
#       "text": "Medicine"
#     },
#     {
#       "relevance": 0.438196,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shekhar_Kapur",
#       "text": "Shekhar Kapur"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3277
#   },
#   "concepts": [
#     {
#       "relevance": 0.927854,
#       "dbpedia_resource": "http://dbpedia.org/resource/KILL",
#       "text": "KILL"
#     },
#     {
#       "relevance": 0.913135,
#       "dbpedia_resource": "http://dbpedia.org/resource/Theft",
#       "text": "Theft"
#     },
#     {
#       "relevance": 0.837631,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.80607,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.681094,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.642317,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automobile",
#       "text": "Automobile"
#     },
#     {
#       "relevance": 0.627019,
#       "dbpedia_resource": "http://dbpedia.org/resource/Looting",
#       "text": "Looting"
#     },
#     {
#       "relevance": 0.615532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1117
#   },
#   "concepts": [
#     {
#       "relevance": 0.919098,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz",
#       "text": "Mercedes-Benz"
#     },
#     {
#       "relevance": 0.723159,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stirling_Moss",
#       "text": "Stirling Moss"
#     },
#     {
#       "relevance": 0.707598,
#       "dbpedia_resource": "http://dbpedia.org/resource/Want",
#       "text": "Want"
#     },
#     {
#       "relevance": 0.685525,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daimler_AG",
#       "text": "Daimler AG"
#     },
#     {
#       "relevance": 0.682582,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mika_H\u00e4kkinen",
#       "text": "Mika H\u00e4kkinen"
#     },
#     {
#       "relevance": 0.669836,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-AMG",
#       "text": "Mercedes-AMG"
#     },
#     {
#       "relevance": 0.66943,
#       "dbpedia_resource": "http://dbpedia.org/resource/Karl_Benz",
#       "text": "Karl Benz"
#     },
#     {
#       "relevance": 0.661751,
#       "dbpedia_resource": "http://dbpedia.org/resource/Formula_One",
#       "text": "Formula One"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 530
#   },
#   "concepts": [
#     {
#       "relevance": 0.921384,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.854413,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.743532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Romance_(love)",
#       "text": "Romance"
#     },
#     {
#       "relevance": 0.667838,
#       "dbpedia_resource": "http://dbpedia.org/resource/2003_in_film",
#       "text": "2003 in film"
#     },
#     {
#       "relevance": 0.662442,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.614421,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lust",
#       "text": "Lust"
#     },
#     {
#       "relevance": 0.611336,
#       "dbpedia_resource": "http://dbpedia.org/resource/Billy_Corgan",
#       "text": "Billy Corgan"
#     },
#     {
#       "relevance": 0.5874,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1520
#   },
#   "concepts": [
#     {
#       "relevance": 0.984419,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.856824,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.768495,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.743123,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.517733,
#       "dbpedia_resource": "http://dbpedia.org/resource/Proposal_of_marriage",
#       "text": "Proposal of marriage"
#     },
#     {
#       "relevance": 0.515028,
#       "dbpedia_resource": "http://dbpedia.org/resource/Alimony",
#       "text": "Alimony"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3457
#   },
#   "concepts": [
#     {
#       "relevance": 0.988228,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.700269,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.636583,
#       "dbpedia_resource": "http://dbpedia.org/resource/Doctor_Who",
#       "text": "Doctor Who"
#     },
#     {
#       "relevance": 0.619782,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.595393,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Five_Doctors",
#       "text": "The Five Doctors"
#     },
#     {
#       "relevance": 0.577806,
#       "dbpedia_resource": "http://dbpedia.org/resource/Master_(Doctor_Who)",
#       "text": "Master"
#     },
#     {
#       "relevance": 0.573813,
#       "dbpedia_resource": "http://dbpedia.org/resource/Third_Doctor",
#       "text": "Third Doctor"
#     },
#     {
#       "relevance": 0.570482,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Christmas_Invasion",
#       "text": "The Christmas Invasion"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1863
#   },
#   "concepts": [
#     {
#       "relevance": 0.913469,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.812904,
#       "dbpedia_resource": "http://dbpedia.org/resource/Poverty",
#       "text": "Poverty"
#     },
#     {
#       "relevance": 0.808302,
#       "dbpedia_resource": "http://dbpedia.org/resource/Oncology",
#       "text": "Oncology"
#     },
#     {
#       "relevance": 0.708283,
#       "dbpedia_resource": "http://dbpedia.org/resource/Cancer",
#       "text": "Cancer"
#     },
#     {
#       "relevance": 0.657557,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illness",
#       "text": "Illness"
#     },
#     {
#       "relevance": 0.646073,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chemotherapy",
#       "text": "Chemotherapy"
#     },
#     {
#       "relevance": 0.642363,
#       "dbpedia_resource": "http://dbpedia.org/resource/Treats",
#       "text": "Treats"
#     },
#     {
#       "relevance": 0.61478,
#       "dbpedia_resource": "http://dbpedia.org/resource/Imaginary_(sociology)",
#       "text": "Imaginary"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1056
#   },
#   "concepts": [
#     {
#       "relevance": 0.919653,
#       "dbpedia_resource": "http://dbpedia.org/resource/Death",
#       "text": "Death"
#     },
#     {
#       "relevance": 0.90459,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hema_Malini",
#       "text": "Hema Malini"
#     },
#     {
#       "relevance": 0.895911,
#       "dbpedia_resource": "http://dbpedia.org/resource/Indian_film_actors",
#       "text": "Indian film actors"
#     },
#     {
#       "relevance": 0.88803,
#       "dbpedia_resource": "http://dbpedia.org/resource/Rajesh_Khanna",
#       "text": "Rajesh Khanna"
#     },
#     {
#       "relevance": 0.875229,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shammi_Kapoor",
#       "text": "Shammi Kapoor"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1410
#   },
#   "concepts": [
#     {
#       "relevance": 0.912942,
#       "dbpedia_resource": "http://dbpedia.org/resource/Termination_of_employment",
#       "text": "Termination of employment"
#     },
#     {
#       "relevance": 0.895778,
#       "dbpedia_resource": "http://dbpedia.org/resource/Time",
#       "text": "Time"
#     },
#     {
#       "relevance": 0.881107,
#       "dbpedia_resource": "http://dbpedia.org/resource/Present",
#       "text": "Present"
#     },
#     {
#       "relevance": 0.815816,
#       "dbpedia_resource": "http://dbpedia.org/resource/Resignation",
#       "text": "Resignation"
#     },
#     {
#       "relevance": 0.815339,
#       "dbpedia_resource": "http://dbpedia.org/resource/Tell",
#       "text": "Tell"
#     },
#     {
#       "relevance": 0.776021,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 952
#   },
#   "concepts": [
#     {
#       "relevance": 0.97906,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.838057,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.835627,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.748564,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.734712,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 743
#   },
#   "concepts": [
#     {
#       "relevance": 0.916093,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.68769,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.661504,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.632706,
#       "dbpedia_resource": "http://dbpedia.org/resource/American_novels",
#       "text": "American novels"
#     },
#     {
#       "relevance": 0.59947,
#       "dbpedia_resource": "http://dbpedia.org/resource/Daughter",
#       "text": "Daughter"
#     },
#     {
#       "relevance": 0.5874,
#       "dbpedia_resource": "http://dbpedia.org/resource/Millionaire",
#       "text": "Millionaire"
#     },
#     {
#       "relevance": 0.585984,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Guardian",
#       "text": "The Guardian"
#     },
#     {
#       "relevance": 0.583758,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Help",
#       "text": "The Help"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 512
#   },
#   "concepts": [
#     {
#       "relevance": 0.907938,
#       "dbpedia_resource": "http://dbpedia.org/resource/Toronto_International_Film_Festival",
#       "text": "Toronto International Film Festival"
#     },
#     {
#       "relevance": 0.85974,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Hanging_Garden",
#       "text": "The Hanging Garden"
#     },
#     {
#       "relevance": 0.8211,
#       "dbpedia_resource": "http://dbpedia.org/resource/Apartment",
#       "text": "Apartment"
#     },
#     {
#       "relevance": 0.811779,
#       "dbpedia_resource": "http://dbpedia.org/resource/Garden",
#       "text": "Garden"
#     },
#     {
#       "relevance": 0.787661,
#       "dbpedia_resource": "http://dbpedia.org/resource/Renting",
#       "text": "Renting"
#     },
#     {
#       "relevance": 0.783044,
#       "dbpedia_resource": "http://dbpedia.org/resource/BAFTA_Award_for_Best_Film",
#       "text": "BAFTA Award for Best Film"
#     },
#     {
#       "relevance": 0.78246,
#       "dbpedia_resource": "http://dbpedia.org/resource/Thom_Fitzgerald",
#       "text": "Thom Fitzgerald"
#     },
#     {
#       "relevance": 0.773139,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chris_Leavins",
#       "text": "Chris Leavins"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 943
#   },
#   "concepts": [
#     {
#       "relevance": 0.911877,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.8188,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mohandas_Karamchand_Gandhi",
#       "text": "Mohandas Karamchand Gandhi"
#     },
#     {
#       "relevance": 0.792379,
#       "dbpedia_resource": "http://dbpedia.org/resource/Truth",
#       "text": "Truth"
#     },
#     {
#       "relevance": 0.791206,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 4569
#   },
#   "concepts": [
#     {
#       "relevance": 0.970475,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.812451,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.552699,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.546322,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.534002,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stepfamily",
#       "text": "Stepfamily"
#     },
#     {
#       "relevance": 0.471133,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.454207,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.447092,
#       "dbpedia_resource": "http://dbpedia.org/resource/Romance_(love)",
#       "text": "Romance"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1772
#   },
#   "concepts": [
#     {
#       "relevance": 0.964151,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.557196,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.528011,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illness",
#       "text": "Illness"
#     },
#     {
#       "relevance": 0.52435,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stay",
#       "text": "Stay"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 477
#   },
#   "concepts": [
#     {
#       "relevance": 0.972027,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.605709,
#       "dbpedia_resource": "http://dbpedia.org/resource/Water",
#       "text": "Water"
#     },
#     {
#       "relevance": 0.590461,
#       "dbpedia_resource": "http://dbpedia.org/resource/Village_(disambiguation)",
#       "text": "Village"
#     },
#     {
#       "relevance": 0.557075,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arid",
#       "text": "Arid"
#     },
#     {
#       "relevance": 0.518154,
#       "dbpedia_resource": "http://dbpedia.org/resource/Villager_(disambiguation)",
#       "text": "Villager"
#     },
#     {
#       "relevance": 0.514293,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.474269,
#       "dbpedia_resource": "http://dbpedia.org/resource/Precipitation_(meteorology)",
#       "text": "Precipitation"
#     },
#     {
#       "relevance": 0.46615,
#       "dbpedia_resource": "http://dbpedia.org/resource/Surface_runoff",
#       "text": "Surface runoff"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3714
#   },
#   "concepts": [
#     {
#       "relevance": 0.94596,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.762857,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.733784,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.729745,
#       "dbpedia_resource": "http://dbpedia.org/resource/Constable",
#       "text": "Constable"
#     },
#     {
#       "relevance": 0.63994,
#       "dbpedia_resource": "http://dbpedia.org/resource/Twist",
#       "text": "Twist"
#     },
#     {
#       "relevance": 0.624213,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.623261,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life_imprisonment",
#       "text": "Life imprisonment"
#     },
#     {
#       "relevance": 0.586417,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminal_justice",
#       "text": "Criminal justice"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 761
#   },
#   "concepts": [
#     {
#       "relevance": 0.920687,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.728868,
#       "dbpedia_resource": "http://dbpedia.org/resource/Celibacy",
#       "text": "Celibacy"
#     },
#     {
#       "relevance": 0.718031,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.561,
#       "dbpedia_resource": "http://dbpedia.org/resource/Clerical_celibacy",
#       "text": "Clerical celibacy"
#     },
#     {
#       "relevance": 0.559968,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2049
#   },
#   "concepts": [
#     {
#       "relevance": 0.894026,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.893535,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automobile",
#       "text": "Automobile"
#     },
#     {
#       "relevance": 0.890717,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suspect",
#       "text": "Suspect"
#     },
#     {
#       "relevance": 0.886784,
#       "dbpedia_resource": "http://dbpedia.org/resource/Piano",
#       "text": "Piano"
#     },
#     {
#       "relevance": 0.882156,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Police",
#       "text": "The Police"
#     },
#     {
#       "relevance": 0.841516,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1375
#   },
#   "concepts": [
#     {
#       "relevance": 0.971182,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.831818,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.738595,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illegal_drug_trade",
#       "text": "Illegal drug trade"
#     },
#     {
#       "relevance": 0.67679,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illegal_immigration",
#       "text": "Illegal immigration"
#     },
#     {
#       "relevance": 0.67221,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminology",
#       "text": "Criminology"
#     },
#     {
#       "relevance": 0.641441,
#       "dbpedia_resource": "http://dbpedia.org/resource/Los_Angeles",
#       "text": "Los Angeles"
#     },
#     {
#       "relevance": 0.587957,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.561532,
#       "dbpedia_resource": "http://dbpedia.org/resource/Organized_crime",
#       "text": "Organized crime"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1079
#   },
#   "concepts": [
#     {
#       "relevance": 0.944702,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.883341,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.847301,
#       "dbpedia_resource": "http://dbpedia.org/resource/Film",
#       "text": "Film"
#     },
#     {
#       "relevance": 0.81055,
#       "dbpedia_resource": "http://dbpedia.org/resource/Reality",
#       "text": "Reality"
#     },
#     {
#       "relevance": 0.792602,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Real_World",
#       "text": "The Real World"
#     },
#     {
#       "relevance": 0.71701,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.683322,
#       "dbpedia_resource": "http://dbpedia.org/resource/Core_issues_in_ethics",
#       "text": "Core issues in ethics"
#     },
#     {
#       "relevance": 0.67509,
#       "dbpedia_resource": "http://dbpedia.org/resource/MTV",
#       "text": "MTV"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1060
#   },
#   "concepts": [
#     {
#       "relevance": 0.937232,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lion",
#       "text": "Lion"
#     },
#     {
#       "relevance": 0.892622,
#       "dbpedia_resource": "http://dbpedia.org/resource/Haathi_Mere_Saathi",
#       "text": "Haathi Mere Saathi"
#     },
#     {
#       "relevance": 0.844019,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.795083,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.770597,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.642474,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wildlife",
#       "text": "Wildlife"
#     },
#     {
#       "relevance": 0.625575,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Animals",
#       "text": "The Animals"
#     },
#     {
#       "relevance": 0.611871,
#       "dbpedia_resource": "http://dbpedia.org/resource/Tiger",
#       "text": "Tiger"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 3649
#   },
#   "concepts": [
#     {
#       "relevance": 0.954282,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide",
#       "text": "Suicide"
#     },
#     {
#       "relevance": 0.763222,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.756604,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.664038,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.659557,
#       "dbpedia_resource": "http://dbpedia.org/resource/Suicide_methods",
#       "text": "Suicide methods"
#     },
#     {
#       "relevance": 0.646717,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.583586,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.560559,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2524
#   },
#   "concepts": [
#     {
#       "relevance": 0.943285,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.709682,
#       "dbpedia_resource": "http://dbpedia.org/resource/Jury",
#       "text": "Jury"
#     },
#     {
#       "relevance": 0.698699,
#       "dbpedia_resource": "http://dbpedia.org/resource/Judge",
#       "text": "Judge"
#     },
#     {
#       "relevance": 0.544387,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lawyer",
#       "text": "Lawyer"
#     },
#     {
#       "relevance": 0.513255,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.499748,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     },
#     {
#       "relevance": 0.439948,
#       "dbpedia_resource": "http://dbpedia.org/resource/Prosecutor",
#       "text": "Prosecutor"
#     },
#     {
#       "relevance": 0.4343,
# ...
#       "text": "Interpersonal relationship"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1008
#   },
#   "concepts": [
#     {
#       "relevance": 0.94962,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother",
#       "text": "Mother"
#     },
#     {
#       "relevance": 0.868669,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.778623,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.66836,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.599379,
#       "dbpedia_resource": "http://dbpedia.org/resource/Parent",
#       "text": "Parent"
#     },
#     {
#       "relevance": 0.585592,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mother_goddess",
#       "text": "Mother goddess"
#     },
#     {
#       "relevance": 0.585069,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nuclear_family",
#       "text": "Nuclear family"
#     },
#     {
#       "relevance": 0.58154,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 471
#   },
#   "concepts": [
#     {
#       "relevance": 0.909651,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.812409,
#       "dbpedia_resource": "http://dbpedia.org/resource/Feudalism",
#       "text": "Feudalism"
#     },
#     {
#       "relevance": 0.7832,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Manor_Studio",
#       "text": "The Manor Studio"
#     },
#     {
#       "relevance": 0.747815,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.731621,
#       "dbpedia_resource": "http://dbpedia.org/resource/Peter_Slabakov",
#       "text": "Peter Slabakov"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 380
#   },
#   "concepts": [
#     {
#       "relevance": 0.91136,
#       "dbpedia_resource": "http://dbpedia.org/resource/Son",
#       "text": "Son"
#     },
#     {
#       "relevance": 0.864502,
#       "dbpedia_resource": "http://dbpedia.org/resource/Asha_Bhosle",
#       "text": "Asha Bhosle"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2426
#   },
#   "concepts": [
#     {
#       "relevance": 0.975889,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.660007,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.41794,
#       "dbpedia_resource": "http://dbpedia.org/resource/Tram_accident",
#       "text": "Tram accident"
#     },
#     {
#       "relevance": 0.408184,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adultery",
#       "text": "Adultery"
#     },
#     {
#       "relevance": 0.344631,
#       "dbpedia_resource": "http://dbpedia.org/resource/Husband",
#       "text": "Husband"
#     },
#     {
#       "relevance": 0.344576,
#       "dbpedia_resource": "http://dbpedia.org/resource/Romance_(love)",
#       "text": "Romance"
#     },
#     {
#       "relevance": 0.343119,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.339309,
#       "dbpedia_resource": "http://dbpedia.org/resource/Accident",
#       "text": "Accident"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 965
#   },
#   "concepts": [
#     {
#       "relevance": 0.893748,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.882924,
#       "dbpedia_resource": "http://dbpedia.org/resource/Awadh",
#       "text": "Awadh"
#     },
#     {
#       "relevance": 0.857646,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.74594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Return",
#       "text": "Return"
#     },
#     {
#       "relevance": 0.72744,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Residents",
#       "text": "The Residents"
#     },
#     {
#       "relevance": 0.724319,
#       "dbpedia_resource": "http://dbpedia.org/resource/Village",
#       "text": "Village"
#     },
#     {
#       "relevance": 0.723759,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.722658,
#       "dbpedia_resource": "http://dbpedia.org/resource/Eye",
#       "text": "Eye"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 996
#   },
#   "concepts": [
#     {
#       "relevance": 0.965677,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     },
#     {
#       "relevance": 0.832721,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.685909,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.519944,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.447517,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sociology",
#       "text": "Sociology"
#     },
#     {
#       "relevance": 0.433079,
#       "dbpedia_resource": "http://dbpedia.org/resource/Affection",
#       "text": "Affection"
#     },
#     {
#       "relevance": 0.430037,
#       "dbpedia_resource": "http://dbpedia.org/resource/Platonic_love",
#       "text": "Platonic love"
#     },
#     {
#       "relevance": 0.427864,
#       "dbpedia_resource": "http://dbpedia.org/resource/Philia",
#       "text": "Philia"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 2438
#   },
#   "concepts": [
#     {
#       "relevance": 0.983964,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.777814,
#       "dbpedia_resource": "http://dbpedia.org/resource/Friendship",
#       "text": "Friendship"
#     },
#     {
#       "relevance": 0.656418,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.558201,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Asylum",
#       "text": "The Asylum"
#     },
#     {
#       "relevance": 0.557309,
#       "dbpedia_resource": "http://dbpedia.org/resource/Meantime_(album)",
#       "text": "Meantime"
#     },
#     {
#       "relevance": 0.557207,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wealth",
#       "text": "Wealth"
#     },
#     {
#       "relevance": 0.556899,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Climax",
#       "text": "The Climax"
#     },
#     {
#       "relevance": 0.544075,
#       "dbpedia_resource": "http://dbpedia.org/resource/Interpersonal_relationship",
#       "text": "Interpersonal relationship"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 989
#   },
#   "concepts": [
#     {
#       "relevance": 0.961521,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.651722,
#       "dbpedia_resource": "http://dbpedia.org/resource/Question",
#       "text": "Question"
#     },
#     {
#       "relevance": 0.564143,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.448426,
#       "dbpedia_resource": "http://dbpedia.org/resource/Father",
#       "text": "Father"
#     },
#     {
#       "relevance": 0.448029,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.433846,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.423877,
#       "dbpedia_resource": "http://dbpedia.org/resource/Answer",
#       "text": "Answer"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 558
#   },
#   "concepts": [
#     {
#       "relevance": 0.958455,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.940164,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.805343,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crimes",
#       "text": "Crimes"
#     },
#     {
#       "relevance": 0.755919,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminal_law",
#       "text": "Criminal law"
#     },
#     {
#       "relevance": 0.746377,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminal_justice",
#       "text": "Criminal justice"
#     },
#     {
#       "relevance": 0.690524,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.685855,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminology",
#       "text": "Criminology"
#     },
#     {
#       "relevance": 0.685576,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime_prevention",
#       "text": "Crime prevention"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 422
#   },
#   "concepts": [
#     {
#       "relevance": 0.948876,
#       "dbpedia_resource": "http://dbpedia.org/resource/Shruti_Haasan",
#       "text": "Shruti Haasan"
#     },
#     {
#       "relevance": 0.815963,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_X-Files",
#       "text": "The X-Files"
#     },
#     {
#       "relevance": 0.794669,
#       "dbpedia_resource": "http://dbpedia.org/resource/Cinema_of_India",
#       "text": "Cinema of India"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 474
#   },
#   "concepts": [
#     {
#       "relevance": 0.949356,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.803424,
#       "dbpedia_resource": "http://dbpedia.org/resource/Love",
#       "text": "Love"
#     },
#     {
#       "relevance": 0.747188,
#       "dbpedia_resource": "http://dbpedia.org/resource/Life",
#       "text": "Life"
#     },
#     {
#       "relevance": 0.674276,
#       "dbpedia_resource": "http://dbpedia.org/resource/Lions_Gate_Entertainment",
#       "text": "Lions Gate Entertainment"
#     },
#     {
#       "relevance": 0.649562,
#       "dbpedia_resource": "http://dbpedia.org/resource/Personal_life",
#       "text": "Personal life"
#     },
#     {
#       "relevance": 0.64248,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Real",
#       "text": "The Real"
#     }
#   ],
#   "language": "en"
# }
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 577
#   },
#   "concepts": [
#     {
#       "relevance": 0.95304,
#       "dbpedia_resource": "http://dbpedia.org/resource/Marriage",
#       "text": "Marriage"
#     },
#     {
#       "relevance": 0.738446,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arranged_marriage",
#       "text": "Arranged marriage"
#     },
#     {
#       "relevance": 0.668243,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wife",
#       "text": "Wife"
#     },
#     {
#       "relevance": 0.613318,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.581145,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sociology",
#       "text": "Sociology"
#     },
#     {
#       "relevance": 0.5607,
#       "dbpedia_resource": "http://dbpedia.org/resource/Officer_(armed_forces)",
#       "text": "Officer"
#     },
#     {
#       "relevance": 0.554838,
#       "dbpedia_resource": "http://dbpedia.org/resource/Higher_education",
#       "text": "Higher education"
#     },
#     {
#       "relevance": 0.5355,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woman",
#       "text": "Woman"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1133
#   },
#   "concepts": [
#     {
#       "relevance": 0.98603,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.6056,
#       "dbpedia_resource": "http://dbpedia.org/resource/Gang",
#       "text": "Gang"
#     },
#     {
#       "relevance": 0.521068,
#       "dbpedia_resource": "http://dbpedia.org/resource/Man",
#       "text": "Man"
#     },
#     {
#       "relevance": 0.485134,
#       "dbpedia_resource": "http://dbpedia.org/resource/Criminal_law",
#       "text": "Criminal law"
#     },
#     {
#       "relevance": 0.473105,
#       "dbpedia_resource": "http://dbpedia.org/resource/Trial_(law)",
#       "text": "Trial"
#     },
#     {
#       "relevance": 0.473029,
#       "dbpedia_resource": "http://dbpedia.org/resource/Police",
#       "text": "Police"
#     },
#     {
#       "relevance": 0.451489,
#       "dbpedia_resource": "http://dbpedia.org/resource/Arrest",
#       "text": "Arrest"
#     },
#     {
#       "relevance": 0.409283,
#       "dbpedia_resource": "http://dbpedia.org/resource/Punk_rock",
#       "text": "Punk rock"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1814
#   },
#   "concepts": [
#     {
#       "relevance": 0.96495,
#       "dbpedia_resource": "http://dbpedia.org/resource/English-language_films",
#       "text": "English-language films"
#     },
#     {
#       "relevance": 0.816034,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sibling",
#       "text": "Sibling"
#     },
#     {
#       "relevance": 0.796424,
#       "dbpedia_resource": "http://dbpedia.org/resource/Wiping",
#       "text": "Wiping"
#     },
#     {
#       "relevance": 0.793552,
#       "dbpedia_resource": "http://dbpedia.org/resource/American_films",
#       "text": "American films"
#     },
#     {
#       "relevance": 0.736593,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mass_murder",
#       "text": "Mass murder"
#     },
#     {
#       "relevance": 0.678154,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.606584,
#       "dbpedia_resource": "http://dbpedia.org/resource/Force",
#       "text": "Force"
#     },
#     {
#       "relevance": 0.580645,
#       "dbpedia_resource": "http://dbpedia.org/resource/Doctor_Who",
#       "text": "Doctor Who"
#     }
#   ],
#   "language": "en"
# }
#
#
# {
#   "usage": {
#     "features": 1,
#     "text_units": 1,
#     "text_characters": 1423
#   },
#   "concepts": [
#     {
#       "relevance": 0.986854,
#       "dbpedia_resource": "http://dbpedia.org/resource/Physician",
#       "text": "Physician"
#     },
#     {
#       "relevance": 0.883547,
#       "dbpedia_resource": "http://dbpedia.org/resource/Medicine",
#       "text": "Medicine"
#     },
#     {
#       "relevance": 0.614047,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime",
#       "text": "Crime"
#     },
#     {
#       "relevance": 0.537173,
#       "dbpedia_resource": "http://dbpedia.org/resource/Family",
#       "text": "Family"
#     },
#     {
#       "relevance": 0.53291,
#       "dbpedia_resource": "http://dbpedia.org/resource/Teacher",
#       "text": "Teacher"
#     },
#     {
#       "relevance": 0.523843,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illness",
#       "text": "Illness"
#     },
#     {
#       "relevance": 0.514973,
#       "dbpedia_resource": "http://dbpedia.org/resource/Psychiatry",
#       "text": "Psychiatry"
#     },
#     {
#       "relevance": 0.470605,
#       "dbpedia_resource": "http://dbpedia.org/resource/Sentence_(linguistics)",
#       "text": "Sentence"
#     }
#   ],
#   "language": "en"
# }

# %%
#string mmatches all the concepts
#adds relevancies
#prints the top ten score

import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
import Features, EntitiesOptions, KeywordsOptions ,ConceptsOptions
import pandas
from operator import itemgetter
def Sort(sub_li): 
    l = len(sub_li) 
    for i in range(0, l): 
        for j in range(0, l-i-1): 
            if (sub_li[j][0] > sub_li[j + 1][0]): 
                tempo = sub_li[j] 
                sub_li[j]= sub_li[j + 1] 
                sub_li[j + 1]= tempo 
    return sub_li
o = input("enter")   
flag = {}
xyz = {}
for j in range(0,k):
    flag[j]=0.0
    try:
        h = response[j]
    except KeyError:
        continue
    for m in range(0,len(response[int(o)]["concepts"])):
        print(m)
        for n in range(0,len(response[j]["concepts"])):
            if(response[int(o)]["concepts"][m]["text"]==response[j]["concepts"][n]["text"]):
                flag[j]=flag[j]+response[int(o)]["concepts"][m]["relevance"]+response[j]["concepts"][n]["relevance"]

for j in range(0,k):
    xyz[j] = (flag[j],x[j])
h = Sort(xyz)
for j in range(0,10):
    print(h[j][1])
# Out:
# enter1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d5cfeb2c9d06> in <module>()
#      26 #    except KeyError:
#      27 #        continue
# ---> 28     for m in range(0,len(response[int(o)]["concepts"])):
#      29         print(m)
#      30         for n in range(0,len(response[j]["concepts"])):
#
# KeyError: 1

# %%
#takes movie name from coref plot
#looks for entities i the wiki page
#notes down every person with an extra subtype or lOOK AT the data you will understand (if they are famous they have a sub type) 
#some shit error comes i dont know what to do about that

import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, MetadataOptions
import wikipedia as wk

imp_people_in_movie = {}
for i in range(0,k):
    
    print(i)
    try:
          q =  wk.page(x[i])
    except wk.exceptions.DisambiguationError as e:
        continue
    natural_language_understanding = NaturalLanguageUnderstandingV1(
              username='06320980-d791-4920-834b-3c5368522608',
              password='UKVXqFnwnNnZ',
              version='2018-03-16',
            )
    imp_people = {}
    response = natural_language_understanding.analyze(
  url=q.url,
  features=Features( entities=EntitiesOptions(
      sentiment=True,
      limit=30)
    )).get_result()
    w=0
    for i in range(0,len(response["entities"])):
        if(response["entities"][i]["type"]=="Person"):
            try:
                b = response["entities"][i]["disambiguation"]
                if(response["entities"][i]["disambiguation"]["subtype"] == []):
                    continue
                else:
                    imp_people[w] = response["entities"][i]["text"]
                    w=w+1
            except KeyError:
                continue
    imp_people_in_movie = (x[i],imp_people) 
    print(imp_people)
print(imp_people_in_movie)
# Out:
# 0
# {0: 'Raj Khanna', 1: 'Prabhu Deva', 2: 'Sonu Sood', 3: 'Murali Sharma'}
# 1
# {0: 'Sanjeev Kumar', 1: 'Kotayya Pratyagatma', 2: 'Keshto Mukherjee'}
# 2
# {0: 'Mr. Amitabh Bachchan', 1: 'Rani Mukerji', 2: 'Satyajit Ray', 3: 'Zoya Akhtar', 4: 'Dibakar Banerjee', 5: 'Mr. Dilip Kumar', 6: 'Katrina Kaif', 7: 'Randeep Hooda', 8: 'Nawazuddin Siddiqui', 9: 'Sadashiv Amrapurkar', 10: 'Karan Johar'}
# 3
# {0: 'Shatrughan Sinha', 1: 'Rehana Sultan', 2: 'David Dhawan'}
# 4
# {0: 'Rajendra Kumar', 1: 'Waheeda Rehman', 2: 'Chandrashekhar', 3: 'Balraj Sahni', 4: 'Sivaji Ganesan', 5: 'C.V. Sridhar'}
# 5
# {}
# 6
# {0: 'Ram', 1: 'Farah Naaz', 2: 'Rishi Kapoor', 3: 'Ashok Saraf', 4: 'Kader Khan', 5: 'Shashikala', 6: 'Bappi Lahiri', 7: 'Aruna Irani', 8: 'Majrooh Sultanpuri', 9: 'Anita Raj'}
# 7
# C:\Users\Vijay\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Vijay\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 8
# {0: 'B. Saroja Devi', 1: 'Leena Chandavarkar', 2: 'Jeetendra', 3: 'Chiranjeevi'}
# 9
# {0: 'Amar Doraiswamy', 1: 'S. D. Burman', 2: 'Kamini Kaushal', 3: 'Yash Chopra', 4: 'Abhi Bhattacharya', 5: 'Dharmendra', 6: 'Uma Devi'}
# 10
# 11
# {0: 'Leela Chitnis', 1: 'Anand Bakshi', 2: 'Tarachand Barjatya', 3: 'Raja Ranbir Singh', 4: 'Supriya Devi', 5: 'Alexandre Dumas', 6: 'Uttam Kumar', 7: 'Rakhee'}
# 12
# {0: 'Rajesh Khanna', 1: 'Asha Parekh', 2: 'Shakti Samanta', 3: 'Kishore Kumar', 4: 'Prem Chopra', 5: 'Asha Bhosle', 6: 'Nasir Hussain', 7: 'Anand Bakshi', 8: 'Rex Harrison', 9: 'Barbara Stanwyck'}
# 13
# {0: 'J. Om Prakash', 1: 'Reena Roy', 2: 'Meenakshi Sheshadri'}
# 14
# {0: 'Ashok Kumar', 1: 'Jeetendra', 2: 'Nutan', 3: 'Nirupa Roy'}
# 15
# {0: 'Master Dinanath'}
# 16
# {0: 'Sharmila Tagore', 1: 'Anand Bakshi'}
# 17
# {0: 'Shammi Kapoor', 1: 'Asha Parekh', 2: 'Shakti Samanta', 3: 'Prem Chopra', 4: 'Mohammed Rafi', 5: 'Mani Ratnam', 6: 'Kamal Hassan'}
# 18
# {0: 'Balraj Sahni', 1: 'Kishore Kumar', 2: 'Parikshit Sahni', 3: 'Rafi Sahab'}
# 19
# {0: 'Dev Anand', 1: 'Kishore Kumar', 2: 'Lata Mangeshkar', 3: 'Waheeda Rehman', 4: 'Shatrughan Sinha', 5: 'Prem Chopra', 6: 'Madan Puri'}
# 20
# {0: 'Shashi Kapoor'}
# 21
# {0: 'Rajesh Khanna', 1: 'Vinod Khanna', 2: 'Manmohan Desai', 3: 'M. G. Ramachandran', 4: 'M. N. Nambiar'}
# 22
# {0: 'Shekhar Kapoor', 1: 'Rajesh Khanna', 2: 'Asit Sen', 3: 'Sharmila Tagore', 4: 'Ashok Kumar', 5: 'Feroz Khan'}
# 23
# {0: 'Rekha', 1: 'Ranjeet'}
# 24
# {0: 'Shashi Kapoor', 1: 'Sharmila Tagore', 2: 'Mohammad Rafi', 3: 'Anand Bakshi'}
# 25
# {0: 'Hema Malini', 1: 'Pran'}
# 26
# {0: 'Rajendra Kumar', 1: 'Prem Chopra', 2: 'Rajendra Nath'}
# 27
# {0: 'Anand Bakshi', 1: 'Rajesh Khanna', 2: 'S. D. Burman', 3: 'Sharmila Tagore', 4: 'Shakti Samanta', 5: 'Hrishikesh Mukherjee', 6: 'Kishore Kumar', 7: 'Lata Mangeshkar', 8: 'Satyajit Ray'}
# 28
# 29
# {0: 'Raveena Tandon', 1: 'Karishma Kapoor', 2: 'Salman Khan', 3: 'Paresh Rawal', 4: 'Aamir Khan', 5: 'Shakti Kapoor', 6: 'Rajkumar Santoshi', 7: 'Shehzad Khan'}
# 30
# {0: 'Anubhav Mohanty'}
# 31
# {0: 'Vijay Bhatt', 1: 'Jeetendra', 2: 'Shatrughan Sinha'}
# 32
# {0: 'Jeetendra', 1: 'Kamini Kaushal'}
# 33
# {0: 'Girdharilal Om Prakash', 1: 'Deven Verma', 2: 'Kishore Kumar', 3: 'Majrooh Sultanpuri', 4: 'Lalita Pawar', 5: 'Aruna Irani', 6: 'Asit Sen', 7: 'Asha Bhosle', 8: 'Hrishikesh Mukherjee'}
# 34
# 35
# 36
# {0: 'Rajesh Khanna', 1: 'Sharmila Tagore', 2: 'Nirupa Roy'}
# 37
# {0: 'Jalal Agha', 1: 'Simi Garewal', 2: 'Asha Bhosle', 3: 'Hari Singh', 4: 'K. A. Abbas', 5: 'Kaifi Azmi', 6: 'Parveen Sultana', 7: 'Lakshmi Shankar'}
# 38
# {0: 'Mohd Rafi', 1: 'Kishore Kumar', 2: 'Sunil Dutt', 3: 'Rajkumar Kohli', 4: 'Sanjeev Kumar', 5: 'Vinod Mehra', 6: 'Neetu Singh', 7: 'Anuradha Paudwal', 8: 'Reena Roy', 9: 'Shatrughan Sinha', 10: 'Rekha'}
# 39
# {0: 'Akkineni Nageswara Rao', 1: 'Jeetendra', 2: 'K. Pratyagatma'}
# 40
# {0: 'Sunny Leone', 1: 'Meera', 2: 'Bhushan Kumar', 3: 'Rahul Dev'}
# 41
# {0: 'William Shatner', 1: 'John Meredyth Lucas', 2: 'William Shakespeare', 3: 'Mark A. Altman', 4: 'France Nuyen', 5: 'Eddie Paskey'}
# 42
# {0: 'Jaya Bachchan', 1: 'Dharmendra', 2: 'Amitabh Bachchan', 3: 'Utpal Dutt', 4: 'Hrishikesh Mukherjee', 5: 'Gulzar', 6: 'Vasant Desai', 7: 'Rajesh Khanna', 8: 'Jayachitra', 9: 'A. K. Hangal', 10: 'Pran', 11: 'Om Prakash'}
# 43
# 44
# {0: 'Dev Anand', 1: 'Zeenat Aman', 2: 'Anand Bakshi', 3: 'Asha Bhosle', 4: 'Kishore Kumar'}
# 45
# 46
# {0: 'V. Shantaram', 1: 'Dina Pathak'}
# 47
# {0: 'Raj Kapoor', 1: 'Randhir Kapoor'}
# 48
# {0: 'Vijaydan Detha'}
# 49
# {0: 'Hema Malini', 1: 'Raaj Kumar', 2: 'Kishore Kumar', 3: 'Vinod Mehra', 4: 'Asit Sen', 5: 'Asha Bhosle', 6: 'Manna Dey', 7: 'Hasrat Jaipuri'}
# 50
# {0: 'Leena Chandavarkar', 1: 'R. Krishnan'}
# 51
# {0: 'Rajesh Khanna', 1: 'Leena Chandavarkar', 2: 'Nasir Ahmed', 3: 'Anand Bakshi', 4: 'Pradeep Kumar', 5: 'Gurnam Singh'}
# 52
# {0: 'Gulzar', 1: 'Shatrughan Sinha', 2: 'Meena Kumari', 3: 'Salil Choudhury', 4: 'Vinod Khanna', 5: 'Keshto Mukherjee', 6: 'Deven Verma', 7: 'Asit Sen', 8: 'Hrishikesh Mukherjee', 9: 'Danny Denzongpa', 10: 'Bimal Roy', 11: 'Asrani', 12: 'A. K. Hangal'}
# 53
# 54
# {0: 'Shashi Kapoor', 1: 'Rajendra Nath', 2: 'Ajit Khan'}
# 55
# {0: 'Amitabh Bachchan', 1: 'Jeetendra', 2: 'Ravikant Nagaich', 3: 'Sivaji Ganesan', 4: 'Farida Jalal'}
# 56
# {0: 'Jaya Prada', 1: 'Jeetendra', 2: 'Sobhan Babu', 3: 'Vanisri', 4: 'Dr. Vishnuvardhan'}
# 57
# {0: 'Shashi Kapoor', 1: 'Father Joseph', 2: 'Anita Guha', 3: 'Subodh Mukherjee', 4: 'Iftekhar', 5: 'Kishore Kumar', 6: 'Asha Bhosle', 7: 'S. D. Burman', 8: 'Lata Mangeshkar'}
# 58
# {0: 'Asha Bhosle', 1: 'Jayshree Gadkar', 2: 'Manna Dey'}
# 59
# {0: 'Chandrachur Singh', 1: 'Arshad Warsi', 2: 'Priya Gill', 3: 'Amitabh Bachchan', 4: 'A.K. Hangal'}
# 60
# {0: 'Rabindranath Tagore', 1: 'Tarachand Barjatya', 2: 'Jaya Bhaduri', 3: 'Kamini Kaushal', 4: 'Sudha'}
# 61
# {}
# 62
# 63
# {}
# 64
# {0: 'Sanjeev Kumar', 1: 'Ravi Tandon', 2: 'Kamini Kaushal', 3: 'Asha Bhosle', 4: 'Leena Chandavarkar', 5: 'Amit Trivedi', 6: 'Kangana Ranaut'}
# 65
# {0: 'Vinod Khanna', 1: 'Rekha'}
# 66
# {0: 'Rajesh Khanna', 1: 'Basu Bhattacharya', 2: 'Sharmila Tagore'}
# 67
# {0: 'Madan Puri', 1: 'Deven Varma', 2: 'Ashok Kumar', 3: 'Keshto Mukherjee', 4: 'Pinchoo Kapoor', 5: 'Rehana Sultan'}
# 68
# 69
# {}
# 70
# {0: 'Abdul Rehman', 1: 'Raj Kapoor', 2: 'Manmohan Desai', 3: 'Fyodor Dostoyevsky', 4: 'Nutan'}
# 71
# {0: 'Dev Anand', 1: 'Hema Malini', 2: 'Prem Chopra', 3: 'Vikram Singh', 4: 'S.D. Burman', 5: 'A. K. Hangal'}
# 72
# {0: 'Rajesh Khanna', 1: 'Sharmila Tagore', 2: 'Prem Chopra', 3: 'Yash Chopra', 4: 'Thomas Hardy', 5: 'Madan Puri', 6: 'Akkineni Nageswara Rao', 7: 'Sahir Ludhianvi', 8: 'Kader Khan', 9: 'Raakhee', 10: 'A.K. Hangal', 11: 'Vanisri'}
# 73
# {0: 'Durga Puja', 1: 'Vyasa'}
# 74
# 75
# {0: 'Pavitra', 1: 'S. Ramanathan', 2: 'Ashok Kumar', 3: 'Vinod Mehra', 4: 'Majrooh Sultanpuri'}
# 76
# {0: 'Vijayadan Detha'}
# 77
# {0: 'Balraj Sahni', 1: 'Farooq Shaikh', 2: 'Shama Zaidi', 3: 'M. S. Sathyu', 4: 'Ismat Chughtai', 5: 'Ustad Bahadur Khan', 6: 'Shyam Benegal'}
# 78
# {0: 'Hema Malini', 1: 'Amitabh Bachchan', 2: 'C.V. Sridhar', 3: 'Jeetendra'}
# 79
# {0: 'Rekha', 1: 'Balraj Sahni', 2: 'Priya Rajvansh', 3: 'Kaifi Azmi'}
# 80
# {0: 'Dev Anand', 1: 'Zeenat Aman', 2: 'Rehman', 3: 'A.K. Hangal'}
# 81
# {}
# 82
# {0: 'Reena Roy'}
# 83
# {0: 'Yash Chopra', 1: 'Hema Malini', 2: 'Dev Anand'}
# 84
# {0: 'Dilip Kumar', 1: 'K. N. Singh'}
# 85
# {0: 'Saif Ali Khan', 1: 'Manisha Koirala', 2: 'Ustad Nusrat Fateh Ali Khan', 3: 'Jackie Chan', 4: 'Namrata Shirodkar', 5: 'Raj Khosla', 6: 'Kabir Bedi', 7: 'Anand Bakshi', 8: 'Vinod Khanna', 9: 'Moushumi Chatterjee'}
# 86
# 87
# {0: 'Sanjeev Kumar', 1: 'Leena Chandavarkar', 2: 'Nirupa Roy'}
# 88
# {0: 'Dara Singh', 1: 'Raj Kapoor'}
# 89
# 90
# {0: 'Rajesh Khanna', 1: 'Amitabh Bachchan', 2: 'Anand Bakshi', 3: 'Hrishikesh Mukherjee', 4: 'Gulzar', 5: 'Prem Nazir', 6: 'Kishore Kumar', 7: 'Rekha', 8: 'Raza Murad', 9: 'Simi Garewal', 10: 'A.K. Hangal'}
# 91
# {0: 'Vasu', 1: 'Subhash Ghai', 2: 'Dilip Kumar', 3: 'Amrish Puri', 4: 'Raaj Kumar', 5: 'Manisha Koirala', 6: 'Anand Bakshi', 7: 'Jackie Shroff', 8: 'Anupam Kher', 9: 'Dina Pathak', 10: 'Gulshan Grover', 11: 'Dalip Tahil'}
# 92
# {0: 'Neetu Singh', 1: 'Vijay Arora', 2: 'Nasir Hussain', 3: 'Zeenat Aman', 4: 'Salim Khan', 5: 'Aamir Khan', 6: 'Ajit Khan', 7: 'Majrooh Sultanpuri', 8: 'Asha Bhosle', 9: 'Javed Akhtar', 10: 'Mohammed Rafi'}
# 93
# {0: 'Anand Raj Anand', 1: 'Sher Khan', 2: 'Sanjay Dutt', 3: 'Priyanka Chopra', 4: 'Puneet Prakash Mehra', 5: 'Apoorva Lakhia', 6: 'Salim Khan', 7: 'Atul Kulkarni', 8: 'Anupama Chopra'}
# 94
# {0: 'M.K. Raina', 1: 'Raakhee', 2: 'Hariprasad Chaurasia', 3: 'Bansi Chandragupta'}
# 95
# {0: 'Sapan Chakraborty', 1: 'Mala Sinha', 2: 'Sunil Dutt', 3: 'Vijay Arora', 4: 'Deven Verma', 5: 'Raaj Kumar', 6: 'Parveen Babi', 7: 'Danny Denzongpa'}
# 96
# {0: 'Mandira Bedi', 1: 'Virendra Saxena', 2: 'Ashutosh Rana', 3: 'Chaitanya Choudhury', 4: 'Tom Alter', 5: 'Roshni Chopra'}
# 97
# {0: 'Rajesh Khanna', 1: 'J. Om Prakash', 2: 'Sanjeev Kumar', 3: 'Mohan Babu', 4: 'Anand Bakshi', 5: 'Dasari Narayana Rao', 6: 'Mohan', 7: 'A. K. Hangal', 8: 'Asrani', 9: 'K. S. Sethumadhavan'}
# 98
# 99
# 100
# {0: 'Kishore Kumar', 1: 'K. N. Singh'}
# 101
# {0: 'Noor Jehan', 1: 'Lata Mangeshkar', 2: 'Ghanshyam', 3: 'Asha Bhosle'}
# 102
# 103
# 104
# {}
# 105
# {0: 'Madan Puri', 1: 'Rekha', 2: 'Shashi Kapoor', 3: 'Ravindra Jain', 4: 'Danny Denzongpa'}
# 106
# {0: 'Sanjeev Kumar', 1: 'Vinod Khanna', 2: 'Om Prakash'}
# 107
# 108
# {0: 'Katrina Kaif', 1: 'Imran Khan', 2: 'Ali Zafar', 3: 'Preity Zinta', 4: 'Parikshat Sahni', 5: 'Aditya Chopra'}
# 109
# {0: 'Sunil Dutt', 1: 'Feroz Khan'}
# 110
# {0: 'Hema Malini', 1: 'Randhir Kapoor', 2: 'Prakash Mehra', 3: 'Vinod Khanna', 4: 'Satyen Kappu', 5: 'Simi Garewal'}
# 111
# {0: 'Usha Khanna', 1: 'Vinod Mehra', 2: 'Rekha'}
# 112
# {0: 'Saif Ali Khan', 1: 'Ashok', 2: 'Ram Kapoor', 3: 'Ashok', 4: 'Bipasha Basu', 5: 'Satish Shah', 6: 'Darshan Jariwala', 7: 'Chunkey Pandey', 8: 'Vashu Bhagnani', 9: 'Y. M. Raj', 10: 'Neeraj Shridhar'}
# 113
# {0: 'Saif Ali Khan', 1: 'Raveena Tandon', 2: 'Sunny Deol'}
# 114
# {0: 'Feroz Khan', 1: 'Saira Banu', 2: 'Dharmendra'}
# 115
# {0: 'Arjun Bijlani'}
# 116
# {0: 'Feroz Khan', 1: 'Akira Kurosawa', 2: 'Majrooh Sultanpuri', 3: 'R.D. Burman', 4: 'Rehana Sultan', 5: 'Sergio Leone', 6: 'Danny Denzongpa'}
# 117
# {0: 'Archana Gupta', 1: 'Jaya Bhaduri', 2: 'Lata Mangeshkar', 3: 'Kishore Kumar', 4: 'Deven Verma', 5: 'Achala Sachdev', 6: 'Suchitra Sen', 7: 'A.K. Hangal'}
# 118
# 119
# {0: 'Mansur'}
# 120
# {0: 'Shammi Kapoor', 1: 'Sanjeev Kumar', 2: 'Asit Sen', 3: 'Asha Bhosle', 4: 'Lou Jacobi', 5: 'Jack Lemmon', 6: 'R.D. Burman'}
# 121
# {0: 'Smita Patil', 1: 'Farooq Shaikh', 2: 'Shreeram Lagoo'}
# 122
# {0: 'Jaya Bhaduri'}
# 123
# {0: 'Basu Chatterjee', 1: 'Amol Palekar', 2: 'Vidya Sinha', 3: 'Salil Chaudhury', 4: 'Mallika Sarabhai', 5: 'Amitabh Bachchan', 6: 'Aparna Sen'}
# 124
# {}
# 125
# {0: 'Tapan Sinha', 1: 'Dilip Kumar'}
# 126
# {}
# 127
# {0: 'Usha Khanna', 1: 'Feroz Khan', 2: 'Deven Verma', 3: 'Tanuja'}
# 128
# {0: 'Jeetendra'}
# 129
# {0: 'Sanjeev Kumar', 1: 'Ashok Kumar', 2: 'Rajesh Khanna', 3: 'Jagdish Kumar', 4: 'Rakesh Roshan', 5: 'Rekha', 6: 'Farida Jalal', 7: 'J. Om Prakash', 8: 'Mumtaz Shanti', 9: 'Keshto Mukherjee'}
# 130
# {0: 'Gulzar', 1: 'Sanjeev Kumar', 2: 'Suchitra Sen', 3: 'Vyjayanthimala', 4: 'Kishore Kumar', 5: 'Tarkeshwari Sinha', 6: 'Sachin Bhowmick', 7: 'Lata Mangeshkar'}
# 131
# {0: 'Raj Kumar', 1: 'Raj Kapoor', 2: 'Lalita Pawar', 3: 'Nutan', 4: 'Hasrat Jaipuri', 5: 'Hrishikesh Mukherjee'}
# 132
# {0: 'Amitabh Bachchan', 1: 'Sukumar Sinha', 2: 'Jaya Bachchan', 3: 'Sharmila Tagore', 4: 'Keshto Mukherjee', 5: 'S. D. Burman', 6: 'Om Prakash', 7: 'Hrishikesh Mukherjee', 8: 'Dharmendra', 9: 'David Abraham Cheulkar', 10: 'Anand Bakshi', 11: 'Kishore Kumar', 12: 'Mohammed Rafi'}
# 133
# {0: 'Amitabh Bachchan', 1: 'Shashi Kapoor', 2: 'Yash Chopra', 3: 'Nirupa Roy', 4: 'Salim Khan', 5: 'Javed Akhtar', 6: 'Parveen Babi', 7: 'Neetu Singh', 8: 'Salim-Javed', 9: 'Dilip Kumar', 10: 'Anupama Chopra', 11: 'John Woo'}
# 134
# {0: 'Ashok Kumar', 1: 'Randhir Kapoor', 2: 'Dara Singh', 3: 'Raj Kapoor', 4: 'Rekha', 5: 'Kishore Kumar', 6: 'R.D. Burman', 7: 'Majrooh Sultanpuri'}
# 135
# {0: 'Rajendra Kumar', 1: 'Raj Kapoor', 2: 'Ravindra Jain', 3: 'Prem Chopra', 4: 'Farida Jalal', 5: 'Aruna Irani', 6: 'Asha Bhosle'}
# 136
# {}
# 137
# {0: 'Dibakar Banerjee'}
# 138
# {0: 'Ravindra Jain', 1: 'Tarachand Barjatya', 2: 'Madan Puri'}
# 139
# {0: 'Usha Mangeshkar', 1: 'Kavi Pradeep', 2: 'Narada', 3: 'Mahendra Kapoor'}
# 140
# 141
# {0: 'Majrooh Sultanpuri', 1: 'Durga', 2: 'R.D. Burman', 3: 'Danny Denzongpa', 4: 'Durga Khote', 5: 'Feroz Khan', 6: 'Ravikant Nagaich', 7: 'Farida Jalal', 8: 'Asha Bhosle', 9: 'Keshto Mukherjee', 10: 'Prem Chopra', 11: 'Parveen Babi'}
# 142
# {0: 'Rishi Kapoor', 1: 'Ravi Tandon', 2: 'Aruna Irani', 3: 'Rakesh Roshan', 4: 'Kishore Kumar'}
# 143
# 144
# {0: 'Shahid Kapoor', 1: 'Sonam Kapoor', 2: 'Anupam Kher'}
# 145
# {0: 'Helen Jairag Richardson', 1: 'Raakhee', 2: 'Majrooh Sultanpuri'}
# 146
# 147
# {0: 'Vikram Bhatt', 1: 'Shakti Kapoor', 2: 'Akhilendra Mishra', 3: 'Rajpal Yadav'}
# 148
# {0: 'Randhir Kapoor', 1: 'Surinder Kapoor', 2: 'Madan Puri', 3: 'Shreeram Lagoo', 4: 'Danny Denzongpa', 5: 'Nirupa Roy'}
# 149
# {0: 'Ranbir Kapoor', 1: 'Rajkumar Santoshi', 2: 'Katrina Kaif', 3: 'Salman Khan', 4: 'Darshan Jariwala', 5: 'Upen Patel'}
# 150
# {}
# 151
# {0: 'Rajendra Kumar', 1: 'Reena Roy', 2: 'Asha Parekh', 3: 'Vasant Desai', 4: 'Ravikant Nagaich', 5: 'Satyendra Kapoor', 6: 'Neetu Singh', 7: 'Feroz Khan'}
# 152
# {0: 'Dimple Kapadia', 1: 'Raj Babbar', 2: 'Kader Khan', 3: 'Raaj Kumar', 4: 'Mithun Chakraborty', 5: 'Anita Raj', 6: 'Vinod Mehra', 7: 'Shakti Kapoor', 8: 'Rajkumar Kohli'}
# 153
# {0: 'Ashok Pradhan', 1: 'Raveena Tandon', 2: 'Sunny Deol'}
# 154
# {}
# 155
# {}
# 156
# {0: 'Thakur Baldev Singh', 1: 'Amitabh Bachchan', 2: 'Anupama Chopra', 3: 'Dharmendra', 4: 'Ramesh Sippy', 5: 'George Roy Hill', 6: 'Amjad Khan', 7: 'Comedian Jagdeep'}
# 157
# {0: 'Sheela', 1: 'Mohammed Rafi', 2: 'Asha Bhosle', 3: 'Mahendra Kapoor'}
# 158
# {0: 'Vinod Mehra', 1: 'Sunil Dutt', 2: 'Reena Roy', 3: 'Moushumi Chatterjee'}
# 159
# 160
# {0: 'Asha Parekh', 1: 'Sunil Dutt', 2: 'Rakesh Roshan', 3: 'Reena Roy', 4: 'Iftekhar', 5: 'Tahir Hussain', 6: 'Bappi Lahiri'}
# 161
# {}
# 162
# {0: 'Rishi Kapoor', 1: 'Pinchoo Kapoor', 2: 'Neetu Singh', 3: 'Rekha'}
# 163
# {}
# 164
# {0: 'Dilip Kumar', 1: 'Madan Puri', 2: 'Saira Banu', 3: 'Prem Chopra', 4: 'Leena Chandavarkar', 5: 'Asit Sen', 6: 'Anand Bakshi', 7: 'Ruma Guha Thakurta', 8: 'Kader Khan', 9: 'Ramesh Sippy', 10: 'Subhash Ghai'}
# 165
# {0: 'Rajesh Khanna', 1: 'Shammi Kapoor', 2: 'Sulakshana Pandit', 3: 'Johnny Walker', 4: 'Farida Jalal', 5: 'Lalita Pawar', 6: 'Kishore Kumar', 7: 'Lata Mangeshkar', 8: 'Ranjeet', 9: 'Viju Khote'}
# 166
# {0: 'Shah Rukh Khan', 1: 'Rani Mukerji', 2: 'Salman Khan', 3: 'Aziz Mirza', 4: 'Alka Yagnik', 5: 'Abhijeet Bhattacharya'}
# 167
# {0: 'Basu Chatterjee', 1: 'Amol Palekar', 2: 'Tarachand Barjatya', 3: 'Ramesh Aravind', 4: 'Ravindra Jain', 5: 'Subhash Ghai', 6: 'Suresh Gopi', 7: 'K. J. Yesudas', 8: 'Mahima Chaudhry', 9: 'Sooraj R. Barjatya'}
# 168
# {0: 'Ravindra Jain', 1: 'Sachin Dev Burman', 2: 'Shashi Kapoor', 3: 'Anand Bakshi', 4: 'Zeenat Aman'}
# 169
# {0: 'Udit Narayan', 1: 'Kader Khan', 2: 'Jackie Shroff', 3: 'Shakti Kapoor', 4: 'Aditya Pancholi'}
# 170
# {0: 'Shashi Kapoor', 1: 'Aruna Irani', 2: 'Ravindra Jain', 3: 'Danny Denzongpa', 4: 'Madan Puri', 5: 'Asrani', 6: 'Shabana Azmi', 7: 'Asit Sen'}
# 171
# {0: 'Hema Malini', 1: 'Rajesh Roshan', 2: 'Rakesh Roshan', 3: 'Rishi Kapoor', 4: 'Rajesh Khanna', 5: 'Randhir Kapoor', 6: 'Vinod Mehra', 7: 'Amjad Khan'}
# 172
# {0: 'Paresh Rawal', 1: 'Sunil Shetty', 2: 'Akshay Kumar', 3: 'Priyadarshan', 4: 'Anu Malik'}
# 173
# {}
# 174
# {0: 'Shatrughan Sinha', 1: 'Reena Roy', 2: 'Subhash Ghai', 3: 'Danny Denzongpa', 4: 'Ajit Khan', 5: 'Madan Puri', 6: 'Sivaji Ganesan', 7: 'Vishnuvardhan', 8: 'Prem Nath'}
# 175
# {}
# 176
# {0: 'Prophet Mohammed', 1: 'Abu Bakr', 2: 'Ali ibn Abi Talib'}
# 177
# {0: 'Imtiaz Ali', 1: 'Ekta Kapoor', 2: 'Shobha Kapoor', 3: 'Niladri Kumar'}
# 178
# {0: 'Neetu Singh', 1: 'Prem Chopra', 2: 'Rajesh Khanna', 3: 'Anand Bakshi', 4: 'R.D. Burman'}
# 179
# {0: 'Tribhovandas Patel', 1: 'Vijay Tendulkar', 2: 'Shyam Benegal', 3: 'Girish Karnad', 4: 'Vanraj Bhatia', 5: 'Kulbhushan Kharbanda', 6: 'Mohan Agashe'}
# 180
# {0: 'Mehbooba Mufti', 1: 'Mufti Mohammad Sayeed'}
# 181
# {0: 'Mrinal Sen', 1: 'Mamata Shankar', 2: 'Mithun Chakraborty'}
# 182
# {0: 'Girish Karnad', 1: 'Amrish Puri', 2: 'Smita Patil', 3: 'Naseeruddin Shah', 4: 'Shabana Azmi', 5: 'Shyam Benegal', 6: 'Anant Nag', 7: 'Vijay Tendulkar', 8: 'Satyadev Dubey', 9: 'Mohan Agashe'}
# 183
# {0: 'Asha Parekh', 1: 'L. V. Prasad', 2: 'Rekha', 3: 'Rajesh Roshan', 4: 'Reena Roy', 5: 'Saroja Devi', 6: 'Madan Puri', 7: 'Vanisri'}
# 184
# {0: 'Shah Rukh Khan', 1: 'Ali Zafar', 2: 'Amit Trivedi', 3: 'Kunal Kapoor'}
# 185
# {0: 'Devendra Goel', 1: 'Deven Verma', 2: 'Asit Sen', 3: 'Shatrughan Sinha'}
# 186
# {0: 'Amjad Khan', 1: 'Leena Chandavarkar'}
# 187
# {0: 'Juhi Chawla', 1: 'Amrita Singh', 2: 'Jackie Shroff', 3: 'Deepak Tijori', 4: 'Yash Chopra', 5: 'Saeed Jaffery'}
# 188
# {0: 'Kunal', 1: 'Akshaye Khanna', 2: 'Anupam Kher', 3: 'Priyanka Chopra', 4: 'Dino Morea', 5: 'Ameesha Patel', 6: 'Suniel Shetty', 7: 'Anupama Chopra', 8: 'Himesh Reshammiya', 9: 'Dharmesh Darshan', 10: 'Lilette Dubey'}
# 189
# {0: 'J. Om Prakash'}
# 190
# {0: 'Ram', 1: 'Shatrughan Sinha', 2: 'Raj Khosla', 3: 'Moushumi Chatterjee', 4: 'Usha Khanna', 5: 'Neetu Singh', 6: 'Ranjeet', 7: 'Asrani'}
# 191
# {0: 'Amitabh Bachchan', 1: 'Om Prakash', 2: 'Harivansh Rai Bachchan', 3: 'Hrishikesh Mukherjee', 4: 'Farida Jalal', 5: 'Rekha', 6: 'Yunus Parvez', 7: 'A. K. Hangal'}
# 192
# {0: 'Amitabh Bachchan', 1: 'Anthony Gonsalves', 2: 'Manmohan Desai', 3: 'Akbar Ilahabadi', 4: 'Rishi Kapoor', 5: 'Vinod Khanna', 6: 'Anand Bakshi', 7: 'Shabana Azmi', 8: 'Sai Baba'}
# 193
# {0: 'Shakti Samanta', 1: 'Ashok Kumar', 2: 'Uttam Kumar', 3: 'Sharmila Tagore', 4: 'Shyamal Mitra'}
# 194
# {0: 'Rajesh Khanna', 1: 'Shakti Samanta', 2: 'Vinod Mehra', 3: 'Simple Kapadia', 4: 'Kishore Kumar', 5: 'Ashok Kumar', 6: 'Dimple Kapadia', 7: 'Anand Bakshi', 8: 'Mohammad Rafi', 9: 'Nirupa Roy', 10: 'R.D. Burman'}
# 195
# {0: 'J. Om Prakash', 1: 'Reena Roy', 2: 'Sulakshana Pandit', 3: 'Sanjeev Kumar', 4: 'Meryl Streep', 5: 'Shoban Babu', 6: 'Sridevi'}
# 196
# {0: 'Bhumika Chawla', 1: 'Amitabh Bachchan', 2: 'Salman Khan', 3: 'Thangar Bachan', 4: 'Pawan Kalyan', 5: 'Prabhu Deva', 6: 'Mahesh Babu', 7: 'Gurdas Maan', 8: 'Sameera Reddy'}
# 197
# {0: 'Raj Kapoor', 1: 'Bindiya Goswami', 2: 'A.K. Hangal'}
# 198
# {0: 'Sanjay Khan', 1: 'Kamini Kaushal', 2: 'Raj Kapoor', 3: 'Parveen Babi', 4: 'Danny Denzongpa'}
# 199
# {0: 'Zeenat Aman', 1: 'Manmohan Desai', 2: 'Dharmendra', 3: 'Neetu Singh', 4: 'Anand Bakshi', 5: 'Bobby Deol', 6: 'Ranjeet'}
# 200
# {0: 'D. Rama Naidu', 1: 'Shobhan Babu', 2: 'Jeetendra', 3: 'Jayachitra'}
# 201
# {0: 'Shashi Kapoor', 1: 'Rishi Kapoor', 2: 'Rajesh Roshan', 3: 'Neetu Singh', 4: 'Ramesh Talwar', 5: 'Yash Chopra', 6: 'Deven Verma', 7: 'Parikshat Sahni'}
# 202
# {0: 'Natalie Portman', 1: 'Zooey Deschanel', 2: 'Katharine Hepburn', 3: 'Emily Browning', 4: 'Roger Ebert', 5: 'Zoe Kazan', 6: 'Jim Carrey', 7: 'Stuart Murdoch', 8: 'Kate Winslet', 9: 'Kirsten Dunst', 10: 'Marc Webb', 11: 'Adam Scott', 12: 'Sarah Jessica Parker'}
# 203
# {0: 'Madan Puri', 1: 'Ravindra Jain', 2: 'Lekh Tandon', 3: 'Tarachand Barjatya', 4: 'Viju Khote'}
# 204
# {0: 'B. R. Chopra', 1: 'Daisy Irani', 2: 'Yash Chopra', 3: 'Hemanta Mukherjee', 4: 'Sunil Dutt', 5: 'Meena Kumari'}
# 205
# {0: 'Amol Palekar', 1: 'Shreeram Lagoo', 2: 'Jalal Agha'}
# 206
# {0: 'Rishi Kapoor', 1: 'Zeenat Aman', 2: 'Amjad Khan', 3: 'Ranbir Kapoor', 4: 'Nasir Hussain', 5: 'Mohammad Rafi', 6: 'Jalal Agha', 7: 'Tom Alter', 8: 'Om Shivpuri', 9: 'Majrooh Sultanpuri'}
# 207
# {0: 'Kabir Das', 1: 'Javed Akhtar', 2: 'Sanjeev Kumar', 3: 'Salim Khan', 4: 'Shashi Kapoor', 5: 'Amitabh Bachchan', 6: 'Rekha', 7: 'Mohan'}
# 208
# 209
# {0: 'Hemant Kumar', 1: 'Abhi Bhattacharya', 2: 'Asha Bhosle', 3: 'Satyen Bose', 4: 'Kavi Pradeep', 5: 'Mohammed Rafi', 6: 'Syed Nazir Ali'}
# 210
# {0: 'L. V. Prasad', 1: 'Rajesh Roshan', 2: 'Reena Roy', 3: 'Bindiya Goswami'}
# 211
# {0: 'Zeenat Aman', 1: 'Anand Bakshi', 2: 'Pradeep Kumar', 3: 'A. K. Hangal'}
# 212
# {0: 'Sulakshana Pandit', 1: 'Jeetendra'}
# 213
# {0: 'Amitabh Bachchan', 1: 'Aruna Irani', 2: 'Kader Khan', 3: 'Vinod Khanna', 4: 'Bharat Bhushan', 5: 'Nirupa Roy'}
# 214
# {0: 'Sanjay Gandhi', 1: 'Indira Gandhi', 2: 'Manohar Singh', 3: 'Shabana Azmi'}
# 215
# {0: 'Vidya Sinha', 1: 'Uttam Kumar', 2: 'Dina Pathak', 3: 'Keshto Mukherjee', 4: 'Shreeram Lagoo'}
# 216
# {0: 'Aparna Sen', 1: 'Hrishikesh Mukherjee', 2: 'Subhash Ghai', 3: 'George Fernandes', 4: 'Raza Murad', 5: 'Amitabh Bachchan', 6: 'Ravindra Jain'}
# 217
# {0: 'Kamal Haasan', 1: 'Rekha'}
# 218
# 219
# {0: 'Shah Rukh Khan', 1: 'Amol Palekar', 2: 'Amitabh Bachchan', 3: 'Sunil Shetty', 4: 'Rani Mukerji', 5: 'Naseeruddin Shah', 6: 'Vijayadan Detha', 7: 'Juhi Chawla', 8: 'M. M. Keeravani', 9: 'Anupam Kher'}
# 220
# {}
# 221
# {0: 'Rakesh Roshan', 1: 'Neetu Singh', 2: 'Rajesh Roshan', 3: 'Basu Chatterjee', 4: 'Utpal Dutt', 5: 'I.S. Johar'}
# 222
# {0: 'Tapan Sinha'}
# 223
# {0: 'Rajinder Krishan', 1: 'Pasupathi'}
# 224
# {}
# 225
# {}
# 226
# {0: 'Prem Nath', 1: 'A. Bhimsingh'}
# 227
# {0: 'Saeed Akhtar Mirza', 1: 'Sriram Lagoo', 2: 'Suresh Oberoi', 3: 'Satish Shah', 4: 'Rohini Hattangadi'}
# 228
# {0: 'Naushad', 1: 'Lata Mangeshkar', 2: 'C. Ramchandra', 3: 'Dilip Kumar', 4: 'Usha Mangeshkar'}
# 229
# {0: 'Rishi Kapoor', 1: 'A. K. Hangal', 2: 'Reena Roy'}
# 230
# {0: 'Ranbir Kapoor', 1: 'Rishi Kapoor', 2: 'Neetu Kapoor', 3: 'Javed Jaffrey', 4: 'Salman Khan'}
# 231
# {0: 'Ashok Kumar', 1: 'Zeenat Aman'}
# 232
# {0: 'Amol Palekar', 1: 'Ranjeeta Kaur', 2: 'Ashok Saraf'}
# 233
# {0: 'Dev Anand', 1: 'Rajesh Roshan', 2: 'Ajit Khan', 3: 'Amjad Khan', 4: 'Prem Chopra', 5: 'Shreeram Lagoo', 6: 'Tom Alter', 7: 'A. K. Hangal'}
# 234
# 235
# {0: 'Smita Patil', 1: 'Farooq Sheikh', 2: 'Muzaffar Ali', 3: 'Nana Patekar', 4: 'Suresh Wadkar', 5: 'Jaidev', 6: 'Jalal Agha'}
# 236
# {0: 'Amjad Khan', 1: 'Jaswant Singh', 2: 'Amitabh Bachchan', 3: 'Wajahat Mirza', 4: 'Anju Mahendru', 5: 'Pran'}
# 237
# {0: 'Ekta Kapoor', 1: 'Anup Soni'}
# 238
# {0: 'Padmini Kolhapure'}
# 239
# {0: 'Randhir Kapoor', 1: 'Amitabh Bachchan', 2: 'Amjad Khan', 3: 'Neetu Singh', 4: 'Rekha', 5: 'Vijayendra Ghatge'}
# 240
# {0: 'Priyadarshan', 1: 'Akshay Kumar', 2: 'Vishwas Rao', 3: 'Kulbhushan Kharbanda', 4: 'Tinu Anand'}
# 241
# {0: 'Vinod Khanna'}
# 242
# {0: 'Asha Parekh', 1: 'Nutan', 2: 'Raj Khosla', 3: 'Lata Mangeshkar', 4: 'Reena Roy', 5: 'Deb Mukherjee', 6: 'Vinod Khanna'}
# 243
# {0: 'Vinod Khanna', 1: 'Prakash Mehra', 2: 'Amitabh Bachchan', 3: 'Amjad Khan', 4: 'Kishore Kumar', 5: 'Shreeram Lagoo'}
# 244
# {0: 'Shashi Kapoor', 1: 'Lata Mangeshkar', 2: 'Raj Kapoor', 3: 'Zeenat Aman', 4: 'Hema Malini', 5: 'Vidya Sinha', 6: 'Sheila Chandra', 7: 'Dimple Kapadia'}
# 245
# 246
# {0: 'Zara Sheikh', 1: 'Amjad Bobby'}
# 247
# {0: 'King David', 1: 'Sir Thomas Malory'}
# 248
# {0: 'Sanjeev Kumar', 1: 'Amitabh Bachchan', 2: 'Mohammed Zahur Khayyam', 3: 'Yash Chopra', 4: 'Sahir Ludhianvi', 5: 'Kamal Hassan', 6: 'Kishore Kumar', 7: 'Gulshan Rai', 8: 'Waheeda Rehman', 9: 'Shoban Babu', 10: 'Hema Malini'}
# 249
# {0: 'Sanjeev Kumar', 1: 'Vidya Sinha', 2: 'Ashok Kumar', 3: 'Basu Chatterjee'}
# 250
# {0: 'Bappi Lahiri', 1: 'Rakesh Roshan'}
# 251
# {0: 'Sanjay Gupta', 1: 'Sanjay Dutt', 2: 'Atul Agnihotri', 3: 'Shakti Kapoor', 4: 'Karishma Kapoor', 5: 'Amitabh Bachchan', 6: 'Raveena Tandon', 7: 'Kader Khan', 8: 'Tanuja', 9: 'John Woo', 10: 'Aditya Pancholi', 11: 'Gulshan Grover'}
# 252
# {}
# 253
# {0: 'Rajesh Roshan', 1: 'Amol Palekar', 2: 'Basu Chatterjee', 3: 'Ranjit Chowdhry', 4: 'Asha Bhosle', 5: 'Patrick Gilmore', 6: 'Asrani', 7: 'Amit Kumar'}
# 254
# {0: 'Mithun Chakraborty', 1: 'Nilu Phule'}
# 255
# {0: 'Asha Parekh', 1: 'Vinod Mehra'}
# 256
# 257
# {0: 'Hemant Kumar'}
# 258
# {0: 'Vinod Khanna', 1: 'Ranjeet', 2: 'Amjad Khan'}
# 259
# {0: 'Hrishikesh Mukherjee', 1: 'Amol Palekar', 2: 'Bindiya Goswami', 3: 'Mukherjee', 4: 'Sachin Bhowmick', 5: 'David Dhawan', 6: 'David', 7: 'Deven Verma', 8: 'Utpal Dutt', 9: 'Om Prakash', 10: 'Rekha', 11: 'Rohit Shetty'}
# 260
# {0: 'Shah Rukh Khan', 1: 'Amjad Khan', 2: 'Anil Kapoor', 3: 'Sanjeev Kumar', 4: 'Lucky Ali'}
# 261
# {0: 'Thakur Vikram Singh', 1: 'Ravindra Jain', 2: 'Hema Malini', 3: 'Jeetendra'}
# 262
# {0: 'Hema Malini', 1: 'Ashok Kumar', 2: 'Rajesh Khanna'}
# 263
# {0: 'Ravi Tandon', 1: 'Rishi Kapoor', 2: 'Neetu Singh'}
# 264
# 265
# 266
# {0: 'Mehul Kumar', 1: 'Alok Nath', 2: 'Akshay Kumar', 3: 'Rajni', 4: 'Suresh Oberoi', 5: 'Farida Jalal', 6: 'Mukesh Rishi', 7: 'Karishma Kapoor', 8: 'Naseeruddin Shah'}
# 267
# {0: 'Tatineni Rama Rao', 1: 'Jaya Prada', 2: 'Jeetendra'}
# 268
# {0: 'Mother Mary', 1: 'Gemini Ganesan', 2: 'Kamal Haasan', 3: 'K. R. Vijaya', 4: 'Jesus', 5: 'G. Devarajan', 6: 'Kannadasan'}
# 269
# {0: 'Kulbhushan Kharbanda', 1: 'Dimple Kapadia', 2: 'Aamir Khan', 3: 'Asha Parekh', 4: 'Prem Chopra', 5: 'Nasir Hussain', 6: 'Sunny Deol', 7: 'Danny Denzongpa'}
# 270
# ---------------------------------------------------------------------------
# WatsonApiException                        Traceback (most recent call last)
# <ipython-input-40-de44cc7a7c09> in <module>()
#      21   features=Features( entities=EntitiesOptions(
#      22       sentiment=True,
# ---> 23       limit=30)
#      24     )).get_result()
#      25     w=0
#
# ~\Anaconda3\lib\site-packages\watson_developer_cloud\natural_language_understanding_v1.py in analyze(self, features, text, html, url, clean, xpath, fallback_to_raw, return_analyzed_text, language, limit_text_characters, **kwargs)
#     213             params=params,
#     214             json=data,
# --> 215             accept_json=True)
#     216         return response
#     217
#
# ~\Anaconda3\lib\site-packages\watson_developer_cloud\watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
#     485             error_info = self._get_error_info(response)
#     486             raise WatsonApiException(response.status_code, error_message,
# --> 487                                      info=error_info, httpResponse=response)
#
# WatsonApiException: Error: unsupported text language: sa, Code: 400 , X-dp-watson-tran-id: gateway01-2095337465 , X-global-transaction-id: 7ecac92c5bb1e7db7ce44ff9

# %%
print(x[0])
